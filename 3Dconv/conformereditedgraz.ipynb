# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

# Specify the path to the zip archive
zip_path = '/content/drive/MyDrive/3dCompressedGraz.zip'

# Specify the directory where you want to extract the files
extract_dir = '/content/'

# Open the zip archive
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # Extract all the contents of the zip archive to the specified directory
    zip_ref.extractall(extract_dir)

print("Folder decompressed successfully.")
# Out:
# Folder decompressed successfully.

# %%
import zipfile

# Specify the path to the zip archive
zip_path = '/content/drive/MyDrive/3dGrazNormalized.zip'

# Specify the directory where you want to extract the files
extract_dir = '/content/'

# Open the zip archive
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # Extract all the contents of the zip archive to the specified directory
    zip_ref.extractall(extract_dir)

print("Folder decompressed successfully.")
# Out:
# Folder decompressed successfully.

# %%
! pip install einops
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting einops
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.6.1

# %%
import argparse
import os
gpus = [0]
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join(map(str, gpus))
import numpy as np
import math
import glob
import random
import itertools
import datetime
import time
import datetime
import sys
import scipy.io

import torchvision.transforms as transforms
from torchvision.utils import save_image, make_grid

from torch.utils.data import DataLoader
from torch.autograd import Variable
from torchsummary import summary
import torch.autograd as autograd
from torchvision.models import vgg19

import torch.nn as nn
import torch.nn.functional as F
import torch
import torch.nn.init as init

from torch.utils.data import Dataset
from PIL import Image
import torchvision.transforms as transforms
from sklearn.decomposition import PCA

import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt

from torch import nn
from torch import Tensor
from PIL import Image
from torchvision.transforms import Compose, Resize, ToTensor
from einops import rearrange, reduce, repeat
from einops.layers.torch import Rearrange, Reduce
# from common_spatial_pattern import csp

import matplotlib.pyplot as plt
# from torch.utils.tensorboard import SummaryWriter
from torch.backends import cudnn
cudnn.benchmark = False
cudnn.deterministic = True

# %%
# writer = SummaryWriter('./TensorBoardX/')
# data shape (115,64,640)

# Convolution module
# use conv to capture local features, instead of postion embedding.
class PatchEmbedding(nn.Module):
    def __init__(self, emb_size=40):
        # self.patch_size = patch_size
        super().__init__()

        self.shallownet = nn.Sequential(
            nn.Conv3d(1, 40, (1, 1, 25), stride=(1,1,1), padding=(0,0,0)),
            nn.Conv3d(40, 40, (6, 7, 1), stride=(1,1,1), padding=(0,0,0)),
        )

        self.shallownet2 = nn.Sequential(
            nn.BatchNorm2d(40),
            nn.ELU(),
            nn.AvgPool2d((1, 75), (1, 15)),  # pooling acts as slicing to obtain 'patch' along the time dimension as in ViT
            nn.Dropout(0.5),
        )

        self.projection = nn.Sequential(
            nn.Conv2d(40, emb_size, (1, 1), stride=(1, 1)),  # transpose, conv could enhance fiting ability slightly
            Rearrange('b e (h) (w) -> b (h w) e'),
        )


    def forward(self, x: Tensor) -> Tensor:
        b, _, _, _, _ = x.shape
        x = self.shallownet(x)
        x = torch.squeeze(x, dim=2)
        x = self.shallownet2(x)
        x = self.projection(x)

        return x


class MultiHeadAttention(nn.Module):
    def __init__(self, emb_size, num_heads, dropout):
        super().__init__()
        self.emb_size = emb_size
        self.num_heads = num_heads
        self.keys = nn.Linear(emb_size, emb_size)
        self.queries = nn.Linear(emb_size, emb_size)
        self.values = nn.Linear(emb_size, emb_size)
        self.att_drop = nn.Dropout(dropout)
        self.projection = nn.Linear(emb_size, emb_size)

    def forward(self, x: Tensor, mask: Tensor = None) -> Tensor:
        queries = rearrange(self.queries(x), "b n (h d) -> b h n d", h=self.num_heads)
        keys = rearrange(self.keys(x), "b n (h d) -> b h n d", h=self.num_heads)
        values = rearrange(self.values(x), "b n (h d) -> b h n d", h=self.num_heads)
        energy = torch.einsum('bhqd, bhkd -> bhqk', queries, keys)
        if mask is not None:
            fill_value = torch.finfo(torch.float32).min
            energy.mask_fill(~mask, fill_value)

        scaling = self.emb_size ** (1 / 2)
        att = F.softmax(energy / scaling, dim=-1)
        att = self.att_drop(att)
        out = torch.einsum('bhal, bhlv -> bhav ', att, values)
        out = rearrange(out, "b h n d -> b n (h d)")
        out = self.projection(out)
        return out


class ResidualAdd(nn.Module):
    def __init__(self, fn):
        super().__init__()
        self.fn = fn

    def forward(self, x, **kwargs):
        res = x
        x = self.fn(x, **kwargs)
        x += res
        return x


class FeedForwardBlock(nn.Sequential):
    def __init__(self, emb_size, expansion, drop_p):
        super().__init__(
            nn.Linear(emb_size, expansion * emb_size),
            nn.GELU(),
            nn.Dropout(drop_p),
            nn.Linear(expansion * emb_size, emb_size),
        )


class GELU(nn.Module):
    def forward(self, input: Tensor) -> Tensor:
        return input*0.5*(1.0+torch.erf(input/math.sqrt(2.0)))


class TransformerEncoderBlock(nn.Sequential):
    def __init__(self,
                 emb_size,
                 num_heads=8,
                 drop_p=0.5,
                 forward_expansion=4,
                 forward_drop_p=0.5):
        super().__init__(
            ResidualAdd(nn.Sequential(
                nn.LayerNorm(emb_size),
                MultiHeadAttention(emb_size, num_heads, drop_p),
                nn.Dropout(drop_p)
            )),
            ResidualAdd(nn.Sequential(
                nn.LayerNorm(emb_size),
                FeedForwardBlock(
                    emb_size, expansion=forward_expansion, drop_p=forward_drop_p),
                nn.Dropout(drop_p)
            )
            ))


class TransformerEncoder(nn.Sequential):
    def __init__(self, depth, emb_size):
        super().__init__(*[TransformerEncoderBlock(emb_size) for _ in range(depth)])


class ClassificationHead(nn.Sequential):
    def __init__(self, emb_size, n_classes):
        super().__init__()

        # global average pooling
        self.clshead = nn.Sequential(
            Reduce('b n e -> b e', reduction='mean'),
            nn.LayerNorm(emb_size),
            nn.Linear(emb_size, n_classes)
        )
        self.fc = nn.Sequential(
            nn.Linear(2440, 256),
            nn.ELU(),
            nn.Dropout(0.5),
            nn.Linear(256, 32),
            nn.ELU(),
            nn.Dropout(0.3),
            nn.Linear(32, 4)
        )

    def forward(self, x):
        x = x.contiguous().view(x.size(0), -1)
        out = self.fc(x)
        return x, out


class Conformer(nn.Sequential):
    def __init__(self, emb_size=40, depth=6, n_classes=4, **kwargs):
        super().__init__(

            PatchEmbedding(emb_size),
            TransformerEncoder(depth, emb_size),
            ClassificationHead(emb_size, n_classes)
        )


class ExP():
    def __init__(self, nsub):
        super(ExP, self).__init__()
        self.batch_size = 36
        #self.batch_size = 12
        self.n_epochs = 150
        self.c_dim = 4
        self.lr = 0.0001
        self.b1 = 0.5
        self.b2 = 0.999
        self.dimension = (190, 50)
        self.nSub = nsub

        self.start_epoch = 0
        self.root = ''

        self.log_write = open("log_subject%d.txt" % self.nSub, "w")


        self.Tensor = torch.cuda.FloatTensor
        self.LongTensor = torch.cuda.LongTensor

        self.criterion_l1 = torch.nn.L1Loss().cuda()
        self.criterion_l2 = torch.nn.MSELoss().cuda()
        self.criterion_cls = torch.nn.CrossEntropyLoss().cuda()

        self.model = Conformer().cuda()
        self.model = nn.DataParallel(self.model, device_ids=[i for i in range(len(gpus))])
        self.model = self.model.cuda()
        # summary(self.model, (1, 22, 1000))


    # Segmentation and Reconstruction (S&R) data augmentation
    def interaug(self, timg, label):
        aug_data = []
        aug_label = []
        for cls4aug in range(4):
            cls_idx = np.where(label == cls4aug + 1)
            tmp_data = timg[cls_idx]
            tmp_data = np.expand_dims(tmp_data, axis=1)
            tmp_label = label[cls_idx]


            tmp_aug_data = np.zeros((int(self.batch_size / 4), 1, 6, 7, 1000))
            for ri in range(int(self.batch_size / 4)):
                for rj in range(8):
                    rand_idx = np.random.randint(0, tmp_data.shape[0], 8)
                    tmp_aug_data[ri, :, :, :, rj * 125:(rj + 1) * 125] = tmp_data[rand_idx[rj], :, :, :, rj * 125:(rj + 1) * 125]

            aug_data.append(tmp_aug_data)
            aug_label.append(tmp_label[:int(self.batch_size / 4)])
        aug_data = np.concatenate(aug_data)
        aug_label = np.concatenate(aug_label)
        aug_shuffle = np.random.permutation(len(aug_data))
        aug_data = aug_data[aug_shuffle, :, :]
        aug_label = aug_label[aug_shuffle]

        aug_data = torch.from_numpy(aug_data).cuda()
        aug_data = aug_data.float()
        aug_label = torch.from_numpy(aug_label-1).cuda()
        aug_label = aug_label.long()
        return aug_data, aug_label

    def get_source_data(self):

        # train data
        self.total_data = scipy.io.loadmat('/content/3dGrazNormalized/3Dnorm_2d_0%dT_P.mat' % self.nSub)
        #self.total_data = scipy.io.loadmat(self.root + 'merged_Graz_2d_T.mat')

        self.train_data = self.total_data['data']
        self.train_label = self.total_data['label']

        # self.train_data = np.transpose(self.train_data, (2, 1, 0))
        self.train_data = np.expand_dims(self.train_data, axis=1)
        self.train_label = np.transpose(self.train_label)

        self.allData = self.train_data
        self.allLabel = self.train_label

        shuffle_num = np.random.permutation(len(self.allData))
        self.allData = self.allData[shuffle_num, :, :, :]
        self.allLabel = self.allLabel[shuffle_num]

        # test data
        self.test_tmp = scipy.io.loadmat('/content/3dGrazNormalized/3Dnorm_2d_0%dE_P.mat' % self.nSub)
        #self.test_tmp = scipy.io.loadmat(self.root + 'merged_Graz_2d_E.mat')
        self.test_data = self.test_tmp['data']
        self.test_label = self.test_tmp['label']

        # self.test_data = np.transpose(self.test_data, (2, 1, 0))
        self.test_data = np.expand_dims(self.test_data, axis=1)
        self.test_label = np.transpose(self.test_label)

        self.testData = self.test_data
        self.testLabel = np.squeeze(self.test_label)

        #print(self.allData)
        # standardize
        target_mean = np.mean(self.allData, axis=0)
        target_std = np.std(self.allData)

        self.allData = (self.allData - target_mean) / target_std
        self.testData = (self.testData - target_mean) / target_std

        # data shape: (trial, conv channel, electrode channel, time samples)
        return self.allData, self.allLabel, self.testData, self.testLabel


    def train(self):

        img, label, test_data, test_label = self.get_source_data()
        img = torch.from_numpy(img)
        label = torch.from_numpy(label - 1)

        dataset = torch.utils.data.TensorDataset(img, label)
        self.dataloader = torch.utils.data.DataLoader(dataset=dataset, batch_size=self.batch_size, shuffle=True)

        test_data = torch.from_numpy(test_data)
        test_label = torch.from_numpy(test_label - 1)
        test_dataset = torch.utils.data.TensorDataset(test_data, test_label)
        self.test_dataloader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=self.batch_size, shuffle=True)

        # Optimizers
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=self.lr, betas=(self.b1, self.b2))

        test_data = Variable(test_data.type(self.Tensor))
        test_label = Variable(test_label.type(self.LongTensor))

        bestAcc = 0
        averAcc = 0
        num = 0
        Y_true = 0
        Y_pred = 0

        # Train the cnn model
        total_step = len(self.dataloader)
        curr_lr = self.lr

        for e in range(self.n_epochs):
            # in_epoch = time.time()
            self.model.train()
            for i, (img, label) in enumerate(self.dataloader):

                img = Variable(img.cuda().type(self.Tensor))
                label = Variable(label.cuda().type(self.LongTensor))

                # data augmentation
                aug_data, aug_label = self.interaug(self.allData, self.allLabel)
                img = torch.cat((img, aug_data))

                label = torch.squeeze(label, dim=1)
                label = torch.cat((label, aug_label))


                tok, outputs = self.model(img)


                loss = self.criterion_cls(outputs, label)

                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()


            # out_epoch = time.time()


            # test process
            if (e + 1) % 1 == 0:
                self.model.eval()
                Tok, Cls = self.model(test_data)

                loss_test = self.criterion_cls(Cls, test_label)
                y_pred = torch.max(Cls, 1)[1]
                acc = float((y_pred == test_label).cpu().numpy().astype(int).sum()) / float(test_label.size(0))
                train_pred = torch.max(outputs, 1)[1]
                train_acc = float((train_pred == label).cpu().numpy().astype(int).sum()) / float(label.size(0))

                print('Epoch:', e,
                      '  Train loss: %.6f' % loss.detach().cpu().numpy(),
                      '  Test loss: %.6f' % loss_test.detach().cpu().numpy(),
                      '  Train accuracy %.6f' % train_acc,
                      '  Test accuracy is %.6f' % acc)

                self.log_write.write(str(e) + "    " +str(loss.detach().cpu().numpy())+"    "+
                                     str(loss_test.detach().cpu().numpy())+"    "+str(train_acc) +"     "+ str(acc)+ "\n")
                num = num + 1
                averAcc = averAcc + acc
                if acc > bestAcc:
                    bestAcc = acc
                    Y_true = test_label
                    Y_pred = y_pred


        torch.save(self.model.module.state_dict(), 'model.pth')
        averAcc = averAcc / num
        print('The average accuracy is:', averAcc)
        print('The best accuracy is:', bestAcc)
        self.log_write.write('The average accuracy is: ' + str(averAcc) + "\n")
        self.log_write.write('The best accuracy is: ' + str(bestAcc) + "\n")

        return bestAcc, averAcc, Y_true, Y_pred
        # writer.close()


def main():
    best = 0
    aver = 0
    result_write = open("sub_result.txt", "w")

    for i in range(9):
        starttime = datetime.datetime.now()


        seed_n = np.random.randint(2021)
        print('seed is ' + str(seed_n))
        random.seed(seed_n)
        np.random.seed(seed_n)
        torch.manual_seed(seed_n)
        torch.cuda.manual_seed(seed_n)
        torch.cuda.manual_seed_all(seed_n)


        print('Subject %d' % (i+1))
        exp = ExP(i + 1)

        bestAcc, averAcc, Y_true, Y_pred = exp.train()
        print('THE BEST ACCURACY IS ' + str(bestAcc))
        result_write.write('Subject ' + str(i + 1) + ' : ' + 'Seed is: ' + str(seed_n) + "\n")
        result_write.write('Subject ' + str(i + 1) + ' : ' + 'The best accuracy is: ' + str(bestAcc) + "\n")
        result_write.write('Subject ' + str(i + 1) + ' : ' + 'The average accuracy is: ' + str(averAcc) + "\n")

        endtime = datetime.datetime.now()
        print('subject %d duration: '%(i+1) + str(endtime - starttime))
        best = best + bestAcc
        aver = aver + averAcc
        if i == 0:
            yt = Y_true
            yp = Y_pred
        else:
            yt = torch.cat((yt, Y_true))
            yp = torch.cat((yp, Y_pred))


    best = best /9
    aver = aver /9

    result_write.write('**The average Best accuracy is: ' + str(best) + "\n")
    result_write.write('The average Aver accuracy is: ' + str(aver) + "\n")
    result_write.close()


if __name__ == "__main__":
    print(time.asctime(time.localtime(time.time())))
    main()
    print(time.asctime(time.localtime(time.time())))
# Out:
# Sat Jun 17 13:16:06 2023
# seed is 1984
# Subject 1
# Epoch: 0   Train loss: 1.415334   Test loss: 1.420502   Train accuracy 0.313433   Test accuracy is 0.250000
# Epoch: 1   Train loss: 1.356543   Test loss: 1.416076   Train accuracy 0.268657   Test accuracy is 0.250000
# Epoch: 2   Train loss: 1.292834   Test loss: 1.357939   Train accuracy 0.402985   Test accuracy is 0.330357
# Epoch: 3   Train loss: 1.091538   Test loss: 1.065883   Train accuracy 0.373134   Test accuracy is 0.482143
# Epoch: 4   Train loss: 0.961606   Test loss: 0.887971   Train accuracy 0.507463   Test accuracy is 0.491071
# Epoch: 5   Train loss: 0.866392   Test loss: 0.832372   Train accuracy 0.507463   Test accuracy is 0.535714
# Epoch: 6   Train loss: 1.162162   Test loss: 0.830873   Train accuracy 0.343284   Test accuracy is 0.526786
# Epoch: 7   Train loss: 0.956724   Test loss: 0.817567   Train accuracy 0.522388   Test accuracy is 0.544643
# Epoch: 8   Train loss: 0.814847   Test loss: 0.731738   Train accuracy 0.552239   Test accuracy is 0.607143
# Epoch: 9   Train loss: 0.681223   Test loss: 0.770817   Train accuracy 0.746269   Test accuracy is 0.633929
# Epoch: 10   Train loss: 0.632663   Test loss: 1.371852   Train accuracy 0.761194   Test accuracy is 0.544643
# Epoch: 11   Train loss: 0.782631   Test loss: 1.880746   Train accuracy 0.537313   Test accuracy is 0.589286
# Epoch: 12   Train loss: 0.606583   Test loss: 0.611468   Train accuracy 0.686567   Test accuracy is 0.678571
# Epoch: 13   Train loss: 0.684261   Test loss: 1.516241   Train accuracy 0.626866   Test accuracy is 0.517857
# Epoch: 14   Train loss: 0.589698   Test loss: 0.882662   Train accuracy 0.746269   Test accuracy is 0.660714
# Epoch: 15   Train loss: 0.544547   Test loss: 0.882776   Train accuracy 0.761194   Test accuracy is 0.651786
# Epoch: 16   Train loss: 0.706927   Test loss: 1.933055   Train accuracy 0.656716   Test accuracy is 0.562500
# Epoch: 17   Train loss: 0.543679   Test loss: 0.609150   Train accuracy 0.746269   Test accuracy is 0.714286
# Epoch: 18   Train loss: 0.652347   Test loss: 0.860995   Train accuracy 0.716418   Test accuracy is 0.642857
# Epoch: 19   Train loss: 0.501454   Test loss: 0.988355   Train accuracy 0.746269   Test accuracy is 0.669643
# Epoch: 20   Train loss: 0.537654   Test loss: 0.965170   Train accuracy 0.746269   Test accuracy is 0.607143
# Epoch: 21   Train loss: 0.514997   Test loss: 0.936830   Train accuracy 0.805970   Test accuracy is 0.651786
# Epoch: 22   Train loss: 0.505238   Test loss: 2.539874   Train accuracy 0.791045   Test accuracy is 0.500000
# Epoch: 23   Train loss: 0.583327   Test loss: 0.670082   Train accuracy 0.731343   Test accuracy is 0.732143
# Epoch: 24   Train loss: 0.370778   Test loss: 0.586028   Train accuracy 0.880597   Test accuracy is 0.705357
# Epoch: 25   Train loss: 0.558658   Test loss: 1.709136   Train accuracy 0.761194   Test accuracy is 0.651786
# Epoch: 26   Train loss: 0.508952   Test loss: 1.067653   Train accuracy 0.761194   Test accuracy is 0.678571
# Epoch: 27   Train loss: 0.562830   Test loss: 0.885889   Train accuracy 0.731343   Test accuracy is 0.696429
# Epoch: 28   Train loss: 0.384891   Test loss: 0.464864   Train accuracy 0.850746   Test accuracy is 0.812500
# Epoch: 29   Train loss: 0.402745   Test loss: 0.759872   Train accuracy 0.910448   Test accuracy is 0.687500
# Epoch: 30   Train loss: 0.417207   Test loss: 0.654157   Train accuracy 0.835821   Test accuracy is 0.758929
# Epoch: 31   Train loss: 0.486973   Test loss: 1.051998   Train accuracy 0.776119   Test accuracy is 0.660714
# Epoch: 32   Train loss: 0.442136   Test loss: 0.550731   Train accuracy 0.835821   Test accuracy is 0.785714
# Epoch: 33   Train loss: 0.412557   Test loss: 0.856887   Train accuracy 0.835821   Test accuracy is 0.758929
# Epoch: 34   Train loss: 0.539106   Test loss: 2.097535   Train accuracy 0.805970   Test accuracy is 0.616071
# Epoch: 35   Train loss: 0.508591   Test loss: 0.664738   Train accuracy 0.746269   Test accuracy is 0.767857
# Epoch: 36   Train loss: 0.367103   Test loss: 0.810847   Train accuracy 0.835821   Test accuracy is 0.785714
# Epoch: 37   Train loss: 0.423922   Test loss: 0.810824   Train accuracy 0.820896   Test accuracy is 0.741071
# Epoch: 38   Train loss: 0.423883   Test loss: 0.849616   Train accuracy 0.805970   Test accuracy is 0.669643
# Epoch: 39   Train loss: 0.359684   Test loss: 2.419704   Train accuracy 0.835821   Test accuracy is 0.669643
# Epoch: 40   Train loss: 0.400235   Test loss: 1.498564   Train accuracy 0.835821   Test accuracy is 0.705357
# Epoch: 41   Train loss: 0.452553   Test loss: 0.471172   Train accuracy 0.791045   Test accuracy is 0.857143
# Epoch: 42   Train loss: 0.292238   Test loss: 0.993925   Train accuracy 0.895522   Test accuracy is 0.750000
# Epoch: 43   Train loss: 0.219545   Test loss: 1.508774   Train accuracy 0.895522   Test accuracy is 0.625000
# Epoch: 44   Train loss: 0.381519   Test loss: 1.167028   Train accuracy 0.865672   Test accuracy is 0.660714
# Epoch: 45   Train loss: 0.393895   Test loss: 0.810058   Train accuracy 0.850746   Test accuracy is 0.794643
# Epoch: 46   Train loss: 0.537051   Test loss: 0.912705   Train accuracy 0.776119   Test accuracy is 0.812500
# Epoch: 47   Train loss: 0.219997   Test loss: 2.103540   Train accuracy 0.925373   Test accuracy is 0.678571
# Epoch: 48   Train loss: 0.274990   Test loss: 0.629503   Train accuracy 0.895522   Test accuracy is 0.776786
# Epoch: 49   Train loss: 0.340825   Test loss: 0.490748   Train accuracy 0.850746   Test accuracy is 0.866071
# Epoch: 50   Train loss: 0.353151   Test loss: 0.595601   Train accuracy 0.865672   Test accuracy is 0.821429
# Epoch: 51   Train loss: 0.330959   Test loss: 1.043275   Train accuracy 0.865672   Test accuracy is 0.741071
# Epoch: 52   Train loss: 0.478235   Test loss: 0.925221   Train accuracy 0.850746   Test accuracy is 0.785714
# Epoch: 53   Train loss: 0.458055   Test loss: 0.655166   Train accuracy 0.805970   Test accuracy is 0.821429
# Epoch: 54   Train loss: 0.274770   Test loss: 0.562422   Train accuracy 0.910448   Test accuracy is 0.875000
# Epoch: 55   Train loss: 0.336323   Test loss: 1.929207   Train accuracy 0.865672   Test accuracy is 0.660714
# Epoch: 56   Train loss: 0.331347   Test loss: 0.429564   Train accuracy 0.865672   Test accuracy is 0.848214
# Epoch: 57   Train loss: 0.428222   Test loss: 0.395697   Train accuracy 0.805970   Test accuracy is 0.866071
# Epoch: 58   Train loss: 0.294358   Test loss: 0.508795   Train accuracy 0.865672   Test accuracy is 0.883929
# Epoch: 59   Train loss: 0.273624   Test loss: 1.841805   Train accuracy 0.925373   Test accuracy is 0.696429
# Epoch: 60   Train loss: 0.457199   Test loss: 0.448486   Train accuracy 0.865672   Test accuracy is 0.875000
# Epoch: 61   Train loss: 0.320957   Test loss: 0.566535   Train accuracy 0.850746   Test accuracy is 0.785714
# Epoch: 62   Train loss: 0.247583   Test loss: 0.682834   Train accuracy 0.895522   Test accuracy is 0.758929
# Epoch: 63   Train loss: 0.335197   Test loss: 0.356861   Train accuracy 0.865672   Test accuracy is 0.883929
# Epoch: 64   Train loss: 0.245955   Test loss: 0.358043   Train accuracy 0.925373   Test accuracy is 0.892857
# Epoch: 65   Train loss: 0.309073   Test loss: 1.613660   Train accuracy 0.910448   Test accuracy is 0.651786
# Epoch: 66   Train loss: 0.340107   Test loss: 1.780599   Train accuracy 0.880597   Test accuracy is 0.723214
# Epoch: 67   Train loss: 0.155694   Test loss: 2.369589   Train accuracy 0.925373   Test accuracy is 0.696429
# Epoch: 68   Train loss: 0.203719   Test loss: 1.446918   Train accuracy 0.910448   Test accuracy is 0.723214
# Epoch: 69   Train loss: 0.212222   Test loss: 0.467769   Train accuracy 0.940299   Test accuracy is 0.883929
# Epoch: 70   Train loss: 0.251482   Test loss: 1.057291   Train accuracy 0.895522   Test accuracy is 0.785714
# Epoch: 71   Train loss: 0.160779   Test loss: 0.488539   Train accuracy 0.940299   Test accuracy is 0.821429
# Epoch: 72   Train loss: 0.243209   Test loss: 1.079962   Train accuracy 0.880597   Test accuracy is 0.714286
# Epoch: 73   Train loss: 0.209641   Test loss: 0.614902   Train accuracy 0.910448   Test accuracy is 0.794643
# Epoch: 74   Train loss: 0.450027   Test loss: 0.441743   Train accuracy 0.820896   Test accuracy is 0.839286
# Epoch: 75   Train loss: 0.277063   Test loss: 0.957346   Train accuracy 0.805970   Test accuracy is 0.758929
# Epoch: 76   Train loss: 0.250907   Test loss: 2.198463   Train accuracy 0.895522   Test accuracy is 0.607143
# Epoch: 77   Train loss: 0.188093   Test loss: 0.530587   Train accuracy 0.955224   Test accuracy is 0.812500
# Epoch: 78   Train loss: 0.285878   Test loss: 1.742207   Train accuracy 0.880597   Test accuracy is 0.723214
# Epoch: 79   Train loss: 0.416787   Test loss: 1.673686   Train accuracy 0.850746   Test accuracy is 0.660714
# Epoch: 80   Train loss: 0.264684   Test loss: 0.753075   Train accuracy 0.895522   Test accuracy is 0.812500
# Epoch: 81   Train loss: 0.258525   Test loss: 0.814886   Train accuracy 0.895522   Test accuracy is 0.821429
# Epoch: 82   Train loss: 0.346616   Test loss: 1.825663   Train accuracy 0.865672   Test accuracy is 0.651786
# Epoch: 83   Train loss: 0.332968   Test loss: 1.167973   Train accuracy 0.835821   Test accuracy is 0.660714
# Epoch: 84   Train loss: 0.187439   Test loss: 0.381140   Train accuracy 0.910448   Test accuracy is 0.839286
# Epoch: 85   Train loss: 0.230685   Test loss: 0.606759   Train accuracy 0.940299   Test accuracy is 0.794643
# Epoch: 86   Train loss: 0.189311   Test loss: 0.420538   Train accuracy 0.940299   Test accuracy is 0.883929
# Epoch: 87   Train loss: 0.287815   Test loss: 0.986260   Train accuracy 0.925373   Test accuracy is 0.812500
# Epoch: 88   Train loss: 0.239521   Test loss: 1.155053   Train accuracy 0.925373   Test accuracy is 0.741071
# Epoch: 89   Train loss: 0.199480   Test loss: 1.083772   Train accuracy 0.940299   Test accuracy is 0.767857
# Epoch: 90   Train loss: 0.155390   Test loss: 0.456201   Train accuracy 0.970149   Test accuracy is 0.839286
# Epoch: 91   Train loss: 0.276882   Test loss: 0.392285   Train accuracy 0.895522   Test accuracy is 0.857143
# Epoch: 92   Train loss: 0.216712   Test loss: 1.609306   Train accuracy 0.910448   Test accuracy is 0.723214
# Epoch: 93   Train loss: 0.257205   Test loss: 0.459167   Train accuracy 0.910448   Test accuracy is 0.883929
# Epoch: 94   Train loss: 0.295243   Test loss: 0.480869   Train accuracy 0.895522   Test accuracy is 0.848214
# Epoch: 95   Train loss: 0.407404   Test loss: 0.405737   Train accuracy 0.805970   Test accuracy is 0.875000
# Epoch: 96   Train loss: 0.177153   Test loss: 0.590909   Train accuracy 0.940299   Test accuracy is 0.839286
# Epoch: 97   Train loss: 0.100734   Test loss: 0.804449   Train accuracy 0.985075   Test accuracy is 0.758929
# Epoch: 98   Train loss: 0.310593   Test loss: 0.455372   Train accuracy 0.895522   Test accuracy is 0.848214
# Epoch: 99   Train loss: 0.172836   Test loss: 0.816961   Train accuracy 0.940299   Test accuracy is 0.794643
# Epoch: 100   Train loss: 0.257978   Test loss: 1.560209   Train accuracy 0.895522   Test accuracy is 0.642857
# Epoch: 101   Train loss: 0.273692   Test loss: 1.051703   Train accuracy 0.880597   Test accuracy is 0.758929
# Epoch: 102   Train loss: 0.203307   Test loss: 1.623973   Train accuracy 0.925373   Test accuracy is 0.705357
# Epoch: 103   Train loss: 0.221644   Test loss: 3.092970   Train accuracy 0.925373   Test accuracy is 0.625000
# Epoch: 104   Train loss: 0.192440   Test loss: 0.771201   Train accuracy 0.910448   Test accuracy is 0.803571
# Epoch: 105   Train loss: 0.195158   Test loss: 1.061339   Train accuracy 0.955224   Test accuracy is 0.758929
# Epoch: 106   Train loss: 0.139220   Test loss: 0.648299   Train accuracy 0.970149   Test accuracy is 0.830357
# Epoch: 107   Train loss: 0.137624   Test loss: 0.507356   Train accuracy 0.955224   Test accuracy is 0.883929
# Epoch: 108   Train loss: 0.086545   Test loss: 2.164564   Train accuracy 0.985075   Test accuracy is 0.669643
# Epoch: 109   Train loss: 0.236275   Test loss: 0.661047   Train accuracy 0.925373   Test accuracy is 0.857143
# Epoch: 110   Train loss: 0.221680   Test loss: 0.974315   Train accuracy 0.925373   Test accuracy is 0.803571
# Epoch: 111   Train loss: 0.197108   Test loss: 0.589933   Train accuracy 0.940299   Test accuracy is 0.857143
# Epoch: 112   Train loss: 0.205599   Test loss: 0.750637   Train accuracy 0.910448   Test accuracy is 0.776786
# Epoch: 113   Train loss: 0.239692   Test loss: 0.383673   Train accuracy 0.925373   Test accuracy is 0.883929
# Epoch: 114   Train loss: 0.292910   Test loss: 0.436421   Train accuracy 0.850746   Test accuracy is 0.848214
# Epoch: 115   Train loss: 0.235345   Test loss: 0.552122   Train accuracy 0.925373   Test accuracy is 0.839286
# Epoch: 116   Train loss: 0.214479   Test loss: 1.135612   Train accuracy 0.925373   Test accuracy is 0.732143
# Epoch: 117   Train loss: 0.216063   Test loss: 1.608580   Train accuracy 0.925373   Test accuracy is 0.651786
# Epoch: 118   Train loss: 0.191501   Test loss: 0.449537   Train accuracy 0.910448   Test accuracy is 0.875000
# Epoch: 119   Train loss: 0.211973   Test loss: 0.530496   Train accuracy 0.940299   Test accuracy is 0.839286
# Epoch: 120   Train loss: 0.195072   Test loss: 0.607099   Train accuracy 0.910448   Test accuracy is 0.883929
# Epoch: 121   Train loss: 0.255306   Test loss: 0.604665   Train accuracy 0.925373   Test accuracy is 0.848214
# Epoch: 122   Train loss: 0.188960   Test loss: 1.024952   Train accuracy 0.925373   Test accuracy is 0.741071
# Epoch: 123   Train loss: 0.251449   Test loss: 0.510459   Train accuracy 0.880597   Test accuracy is 0.857143
# Epoch: 124   Train loss: 0.177483   Test loss: 0.513229   Train accuracy 0.925373   Test accuracy is 0.875000
# Epoch: 125   Train loss: 0.205072   Test loss: 0.467965   Train accuracy 0.880597   Test accuracy is 0.892857
# Epoch: 126   Train loss: 0.162565   Test loss: 0.790896   Train accuracy 0.955224   Test accuracy is 0.821429
# Epoch: 127   Train loss: 0.194785   Test loss: 1.006416   Train accuracy 0.910448   Test accuracy is 0.723214
# Epoch: 128   Train loss: 0.162884   Test loss: 2.409033   Train accuracy 0.880597   Test accuracy is 0.687500
# Epoch: 129   Train loss: 0.169849   Test loss: 0.958664   Train accuracy 0.940299   Test accuracy is 0.803571
# Epoch: 130   Train loss: 0.233443   Test loss: 1.046191   Train accuracy 0.925373   Test accuracy is 0.732143
# Epoch: 131   Train loss: 0.136220   Test loss: 0.585540   Train accuracy 0.940299   Test accuracy is 0.875000
# Epoch: 132   Train loss: 0.154556   Test loss: 1.415745   Train accuracy 0.925373   Test accuracy is 0.741071
# Epoch: 133   Train loss: 0.143464   Test loss: 0.743565   Train accuracy 0.955224   Test accuracy is 0.803571
# Epoch: 134   Train loss: 0.167425   Test loss: 2.151937   Train accuracy 0.940299   Test accuracy is 0.687500
# Epoch: 135   Train loss: 0.172116   Test loss: 0.856746   Train accuracy 0.940299   Test accuracy is 0.785714
# Epoch: 136   Train loss: 0.389104   Test loss: 0.639370   Train accuracy 0.880597   Test accuracy is 0.794643
# Epoch: 137   Train loss: 0.101741   Test loss: 0.541048   Train accuracy 0.940299   Test accuracy is 0.857143
# Epoch: 138   Train loss: 0.078385   Test loss: 0.616578   Train accuracy 0.985075   Test accuracy is 0.830357
# Epoch: 139   Train loss: 0.188444   Test loss: 1.642327   Train accuracy 0.910448   Test accuracy is 0.750000
# Epoch: 140   Train loss: 0.067998   Test loss: 0.736943   Train accuracy 0.985075   Test accuracy is 0.839286
# Epoch: 141   Train loss: 0.154465   Test loss: 0.891756   Train accuracy 0.940299   Test accuracy is 0.821429
# Epoch: 142   Train loss: 0.198565   Test loss: 0.422099   Train accuracy 0.895522   Test accuracy is 0.883929
# Epoch: 143   Train loss: 0.144904   Test loss: 0.683296   Train accuracy 0.940299   Test accuracy is 0.839286
# Epoch: 144   Train loss: 0.151030   Test loss: 0.687704   Train accuracy 0.940299   Test accuracy is 0.848214
# Epoch: 145   Train loss: 0.218790   Test loss: 0.448826   Train accuracy 0.925373   Test accuracy is 0.866071
# Epoch: 146   Train loss: 0.155900   Test loss: 0.685654   Train accuracy 0.940299   Test accuracy is 0.830357
# Epoch: 147   Train loss: 0.385598   Test loss: 2.869889   Train accuracy 0.895522   Test accuracy is 0.669643
# Epoch: 148   Train loss: 0.132489   Test loss: 0.823010   Train accuracy 0.955224   Test accuracy is 0.821429
# Epoch: 149   Train loss: 0.248495   Test loss: 0.463960   Train accuracy 0.910448   Test accuracy is 0.866071
# The average accuracy is: 0.7447619047619047
# The best accuracy is: 0.8928571428571429
# THE BEST ACCURACY IS 0.8928571428571429
# subject 1 duration: 0:09:29.464295
# seed is 1942
# Subject 2
# Epoch: 0   Train loss: 1.417124   Test loss: 1.386356   Train accuracy 0.279412   Test accuracy is 0.241071
# Epoch: 1   Train loss: 1.398916   Test loss: 1.389090   Train accuracy 0.279412   Test accuracy is 0.241071
# Epoch: 2   Train loss: 1.389958   Test loss: 1.385844   Train accuracy 0.250000   Test accuracy is 0.258929
# Epoch: 3   Train loss: 1.446524   Test loss: 1.385080   Train accuracy 0.176471   Test accuracy is 0.285714
# Epoch: 4   Train loss: 1.419974   Test loss: 1.386575   Train accuracy 0.294118   Test accuracy is 0.294643
# Epoch: 5   Train loss: 1.394199   Test loss: 1.382478   Train accuracy 0.264706   Test accuracy is 0.241071
# Epoch: 6   Train loss: 1.380347   Test loss: 1.386903   Train accuracy 0.279412   Test accuracy is 0.258929
# Epoch: 7   Train loss: 1.391343   Test loss: 1.382299   Train accuracy 0.235294   Test accuracy is 0.303571
# Epoch: 8   Train loss: 1.387589   Test loss: 1.381827   Train accuracy 0.308824   Test accuracy is 0.250000
# Epoch: 9   Train loss: 1.383592   Test loss: 1.381174   Train accuracy 0.279412   Test accuracy is 0.276786
# Epoch: 10   Train loss: 1.400400   Test loss: 1.379011   Train accuracy 0.264706   Test accuracy is 0.303571
# Epoch: 11   Train loss: 1.371274   Test loss: 1.380216   Train accuracy 0.323529   Test accuracy is 0.241071
# Epoch: 12   Train loss: 1.418375   Test loss: 1.379876   Train accuracy 0.220588   Test accuracy is 0.285714
# Epoch: 13   Train loss: 1.363577   Test loss: 1.388308   Train accuracy 0.279412   Test accuracy is 0.232143
# Epoch: 14   Train loss: 1.409799   Test loss: 1.387647   Train accuracy 0.294118   Test accuracy is 0.312500
# Epoch: 15   Train loss: 1.339658   Test loss: 1.401315   Train accuracy 0.338235   Test accuracy is 0.250000
# Epoch: 16   Train loss: 1.323105   Test loss: 1.403895   Train accuracy 0.308824   Test accuracy is 0.294643
# Epoch: 17   Train loss: 1.361164   Test loss: 1.540183   Train accuracy 0.338235   Test accuracy is 0.276786
# Epoch: 18   Train loss: 1.359739   Test loss: 1.481457   Train accuracy 0.382353   Test accuracy is 0.250000
# Epoch: 19   Train loss: 1.304964   Test loss: 1.540933   Train accuracy 0.426471   Test accuracy is 0.321429
# Epoch: 20   Train loss: 1.361405   Test loss: 1.885070   Train accuracy 0.323529   Test accuracy is 0.312500
# Epoch: 21   Train loss: 1.250750   Test loss: 1.553804   Train accuracy 0.411765   Test accuracy is 0.321429
# Epoch: 22   Train loss: 1.294152   Test loss: 1.457555   Train accuracy 0.397059   Test accuracy is 0.357143
# Epoch: 23   Train loss: 1.282298   Test loss: 1.587836   Train accuracy 0.382353   Test accuracy is 0.303571
# Epoch: 24   Train loss: 1.131500   Test loss: 1.641166   Train accuracy 0.441176   Test accuracy is 0.339286
# Epoch: 25   Train loss: 1.209238   Test loss: 2.583740   Train accuracy 0.411765   Test accuracy is 0.285714
# Epoch: 26   Train loss: 1.149010   Test loss: 1.504261   Train accuracy 0.411765   Test accuracy is 0.410714
# Epoch: 27   Train loss: 1.184064   Test loss: 2.655256   Train accuracy 0.441176   Test accuracy is 0.321429
# Epoch: 28   Train loss: 1.080910   Test loss: 1.599828   Train accuracy 0.455882   Test accuracy is 0.375000
# Epoch: 29   Train loss: 1.092606   Test loss: 1.339706   Train accuracy 0.544118   Test accuracy is 0.428571
# Epoch: 30   Train loss: 1.075047   Test loss: 1.604898   Train accuracy 0.470588   Test accuracy is 0.383929
# Epoch: 31   Train loss: 1.082824   Test loss: 1.466668   Train accuracy 0.485294   Test accuracy is 0.437500
# Epoch: 32   Train loss: 1.180369   Test loss: 1.522257   Train accuracy 0.397059   Test accuracy is 0.419643
# Epoch: 33   Train loss: 1.110314   Test loss: 1.368789   Train accuracy 0.485294   Test accuracy is 0.464286
# Epoch: 34   Train loss: 1.032570   Test loss: 1.789518   Train accuracy 0.573529   Test accuracy is 0.410714
# Epoch: 35   Train loss: 1.179652   Test loss: 2.179705   Train accuracy 0.455882   Test accuracy is 0.348214
# Epoch: 36   Train loss: 1.154204   Test loss: 1.618313   Train accuracy 0.441176   Test accuracy is 0.437500
# Epoch: 37   Train loss: 0.899341   Test loss: 1.592767   Train accuracy 0.617647   Test accuracy is 0.428571
# Epoch: 38   Train loss: 0.996117   Test loss: 1.525434   Train accuracy 0.558824   Test accuracy is 0.446429
# Epoch: 39   Train loss: 0.919415   Test loss: 1.950661   Train accuracy 0.514706   Test accuracy is 0.392857
# Epoch: 40   Train loss: 1.070274   Test loss: 1.608382   Train accuracy 0.573529   Test accuracy is 0.428571
# Epoch: 41   Train loss: 1.015955   Test loss: 1.573177   Train accuracy 0.514706   Test accuracy is 0.446429
# Epoch: 42   Train loss: 0.889784   Test loss: 1.771701   Train accuracy 0.602941   Test accuracy is 0.410714
# Epoch: 43   Train loss: 0.934248   Test loss: 1.590666   Train accuracy 0.544118   Test accuracy is 0.482143
# Epoch: 44   Train loss: 0.873991   Test loss: 1.694525   Train accuracy 0.573529   Test accuracy is 0.500000
# Epoch: 45   Train loss: 0.801487   Test loss: 1.748188   Train accuracy 0.647059   Test accuracy is 0.401786
# Epoch: 46   Train loss: 1.097498   Test loss: 1.736731   Train accuracy 0.470588   Test accuracy is 0.446429
# Epoch: 47   Train loss: 0.907293   Test loss: 1.483357   Train accuracy 0.544118   Test accuracy is 0.473214
# Epoch: 48   Train loss: 0.963194   Test loss: 1.985214   Train accuracy 0.529412   Test accuracy is 0.419643
# Epoch: 49   Train loss: 0.897005   Test loss: 1.810180   Train accuracy 0.573529   Test accuracy is 0.428571
# Epoch: 50   Train loss: 0.945631   Test loss: 2.100861   Train accuracy 0.500000   Test accuracy is 0.419643
# Epoch: 51   Train loss: 1.105772   Test loss: 1.482955   Train accuracy 0.485294   Test accuracy is 0.517857
# Epoch: 52   Train loss: 0.902945   Test loss: 1.768889   Train accuracy 0.617647   Test accuracy is 0.428571
# Epoch: 53   Train loss: 0.841438   Test loss: 1.477274   Train accuracy 0.647059   Test accuracy is 0.535714
# Epoch: 54   Train loss: 0.941193   Test loss: 1.439687   Train accuracy 0.514706   Test accuracy is 0.482143
# Epoch: 55   Train loss: 0.943252   Test loss: 1.505300   Train accuracy 0.588235   Test accuracy is 0.482143
# Epoch: 56   Train loss: 0.767898   Test loss: 1.430837   Train accuracy 0.647059   Test accuracy is 0.526786
# Epoch: 57   Train loss: 1.001540   Test loss: 1.616863   Train accuracy 0.632353   Test accuracy is 0.473214
# Epoch: 58   Train loss: 0.711013   Test loss: 1.476126   Train accuracy 0.632353   Test accuracy is 0.553571
# Epoch: 59   Train loss: 0.935635   Test loss: 1.624867   Train accuracy 0.588235   Test accuracy is 0.464286
# Epoch: 60   Train loss: 0.949537   Test loss: 1.773342   Train accuracy 0.544118   Test accuracy is 0.410714
# Epoch: 61   Train loss: 0.930724   Test loss: 1.950554   Train accuracy 0.602941   Test accuracy is 0.419643
# Epoch: 62   Train loss: 0.769779   Test loss: 1.586760   Train accuracy 0.705882   Test accuracy is 0.446429
# Epoch: 63   Train loss: 0.974603   Test loss: 1.735989   Train accuracy 0.558824   Test accuracy is 0.446429
# Epoch: 64   Train loss: 0.729068   Test loss: 1.628688   Train accuracy 0.691176   Test accuracy is 0.508929
# Epoch: 65   Train loss: 0.810475   Test loss: 1.596091   Train accuracy 0.691176   Test accuracy is 0.508929
# Epoch: 66   Train loss: 0.848249   Test loss: 1.435061   Train accuracy 0.647059   Test accuracy is 0.544643
# Epoch: 67   Train loss: 0.759337   Test loss: 1.473326   Train accuracy 0.691176   Test accuracy is 0.508929
# Epoch: 68   Train loss: 0.753354   Test loss: 1.498340   Train accuracy 0.647059   Test accuracy is 0.544643
# Epoch: 69   Train loss: 0.851498   Test loss: 1.669907   Train accuracy 0.632353   Test accuracy is 0.428571
# Epoch: 70   Train loss: 0.917054   Test loss: 1.527138   Train accuracy 0.602941   Test accuracy is 0.544643
# Epoch: 71   Train loss: 0.833817   Test loss: 1.504213   Train accuracy 0.558824   Test accuracy is 0.517857
# Epoch: 72   Train loss: 0.742254   Test loss: 1.952246   Train accuracy 0.632353   Test accuracy is 0.410714
# Epoch: 73   Train loss: 0.576882   Test loss: 1.720512   Train accuracy 0.750000   Test accuracy is 0.482143
# Epoch: 74   Train loss: 0.890137   Test loss: 2.214396   Train accuracy 0.544118   Test accuracy is 0.339286
# Epoch: 75   Train loss: 0.721630   Test loss: 1.957002   Train accuracy 0.661765   Test accuracy is 0.428571
# Epoch: 76   Train loss: 0.752170   Test loss: 1.802620   Train accuracy 0.750000   Test accuracy is 0.473214
# Epoch: 77   Train loss: 0.774357   Test loss: 1.753460   Train accuracy 0.661765   Test accuracy is 0.500000
# Epoch: 78   Train loss: 0.683797   Test loss: 1.815073   Train accuracy 0.735294   Test accuracy is 0.464286
# Epoch: 79   Train loss: 0.876613   Test loss: 1.584119   Train accuracy 0.602941   Test accuracy is 0.535714
# Epoch: 80   Train loss: 0.919186   Test loss: 1.902050   Train accuracy 0.617647   Test accuracy is 0.428571
# Epoch: 81   Train loss: 0.688090   Test loss: 1.451431   Train accuracy 0.661765   Test accuracy is 0.526786
# Epoch: 82   Train loss: 0.891544   Test loss: 2.032336   Train accuracy 0.588235   Test accuracy is 0.428571
# Epoch: 83   Train loss: 0.676727   Test loss: 2.107267   Train accuracy 0.691176   Test accuracy is 0.473214
# Epoch: 84   Train loss: 0.776255   Test loss: 2.081730   Train accuracy 0.705882   Test accuracy is 0.446429
# Epoch: 85   Train loss: 0.746426   Test loss: 2.460196   Train accuracy 0.661765   Test accuracy is 0.410714
# Epoch: 86   Train loss: 0.668799   Test loss: 2.049693   Train accuracy 0.705882   Test accuracy is 0.464286
# Epoch: 87   Train loss: 0.670140   Test loss: 1.693525   Train accuracy 0.750000   Test accuracy is 0.508929
# Epoch: 88   Train loss: 0.874200   Test loss: 1.606444   Train accuracy 0.602941   Test accuracy is 0.517857
# Epoch: 89   Train loss: 0.645265   Test loss: 1.787452   Train accuracy 0.750000   Test accuracy is 0.508929
# Epoch: 90   Train loss: 0.787065   Test loss: 1.661350   Train accuracy 0.676471   Test accuracy is 0.500000
# Epoch: 91   Train loss: 0.725103   Test loss: 1.706438   Train accuracy 0.676471   Test accuracy is 0.508929
# Epoch: 92   Train loss: 0.796267   Test loss: 2.342890   Train accuracy 0.676471   Test accuracy is 0.357143
# Epoch: 93   Train loss: 0.916814   Test loss: 1.571399   Train accuracy 0.573529   Test accuracy is 0.500000
# Epoch: 94   Train loss: 0.720909   Test loss: 1.764070   Train accuracy 0.764706   Test accuracy is 0.491071
# Epoch: 95   Train loss: 0.698812   Test loss: 2.182925   Train accuracy 0.705882   Test accuracy is 0.473214
# Epoch: 96   Train loss: 0.766752   Test loss: 1.480655   Train accuracy 0.676471   Test accuracy is 0.553571
# Epoch: 97   Train loss: 0.662792   Test loss: 1.633271   Train accuracy 0.720588   Test accuracy is 0.526786
# Epoch: 98   Train loss: 0.799621   Test loss: 1.453448   Train accuracy 0.661765   Test accuracy is 0.517857
# Epoch: 99   Train loss: 0.814968   Test loss: 1.516434   Train accuracy 0.764706   Test accuracy is 0.491071
# Epoch: 100   Train loss: 0.797671   Test loss: 1.792130   Train accuracy 0.632353   Test accuracy is 0.508929
# Epoch: 101   Train loss: 0.638832   Test loss: 1.547499   Train accuracy 0.779412   Test accuracy is 0.580357
# Epoch: 102   Train loss: 0.942671   Test loss: 1.465762   Train accuracy 0.529412   Test accuracy is 0.500000
# Epoch: 103   Train loss: 0.787242   Test loss: 1.500491   Train accuracy 0.617647   Test accuracy is 0.526786
# Epoch: 104   Train loss: 0.848292   Test loss: 1.597016   Train accuracy 0.617647   Test accuracy is 0.455357
# Epoch: 105   Train loss: 0.727928   Test loss: 1.465100   Train accuracy 0.705882   Test accuracy is 0.571429
# Epoch: 106   Train loss: 0.769019   Test loss: 1.390588   Train accuracy 0.705882   Test accuracy is 0.544643
# Epoch: 107   Train loss: 0.716995   Test loss: 1.747303   Train accuracy 0.632353   Test accuracy is 0.410714
# Epoch: 108   Train loss: 0.716810   Test loss: 1.568826   Train accuracy 0.676471   Test accuracy is 0.508929
# Epoch: 109   Train loss: 0.684333   Test loss: 1.495926   Train accuracy 0.794118   Test accuracy is 0.491071
# Epoch: 110   Train loss: 0.763304   Test loss: 1.681278   Train accuracy 0.691176   Test accuracy is 0.562500
# Epoch: 111   Train loss: 0.617409   Test loss: 1.723132   Train accuracy 0.779412   Test accuracy is 0.535714
# Epoch: 112   Train loss: 0.850633   Test loss: 1.608754   Train accuracy 0.647059   Test accuracy is 0.491071
# Epoch: 113   Train loss: 0.567753   Test loss: 1.501907   Train accuracy 0.794118   Test accuracy is 0.491071
# Epoch: 114   Train loss: 0.745663   Test loss: 1.537473   Train accuracy 0.720588   Test accuracy is 0.535714
# Epoch: 115   Train loss: 0.631349   Test loss: 1.647244   Train accuracy 0.750000   Test accuracy is 0.500000
# Epoch: 116   Train loss: 0.633820   Test loss: 1.602442   Train accuracy 0.735294   Test accuracy is 0.526786
# Epoch: 117   Train loss: 0.617335   Test loss: 1.773301   Train accuracy 0.720588   Test accuracy is 0.473214
# Epoch: 118   Train loss: 0.520745   Test loss: 1.455259   Train accuracy 0.764706   Test accuracy is 0.553571
# Epoch: 119   Train loss: 0.927028   Test loss: 1.809331   Train accuracy 0.632353   Test accuracy is 0.401786
# Epoch: 120   Train loss: 0.555371   Test loss: 1.433145   Train accuracy 0.779412   Test accuracy is 0.535714
# Epoch: 121   Train loss: 0.705110   Test loss: 1.586032   Train accuracy 0.676471   Test accuracy is 0.535714
# Epoch: 122   Train loss: 0.754941   Test loss: 1.616743   Train accuracy 0.661765   Test accuracy is 0.535714
# Epoch: 123   Train loss: 0.528629   Test loss: 1.927528   Train accuracy 0.779412   Test accuracy is 0.491071
# Epoch: 124   Train loss: 0.649501   Test loss: 1.411892   Train accuracy 0.720588   Test accuracy is 0.553571
# Epoch: 125   Train loss: 0.730722   Test loss: 1.595528   Train accuracy 0.676471   Test accuracy is 0.517857
# Epoch: 126   Train loss: 0.549210   Test loss: 1.552892   Train accuracy 0.764706   Test accuracy is 0.562500
# Epoch: 127   Train loss: 0.729925   Test loss: 1.580970   Train accuracy 0.720588   Test accuracy is 0.535714
# Epoch: 128   Train loss: 0.720122   Test loss: 1.470153   Train accuracy 0.720588   Test accuracy is 0.535714
# Epoch: 129   Train loss: 0.574644   Test loss: 2.490578   Train accuracy 0.838235   Test accuracy is 0.401786
# Epoch: 130   Train loss: 0.523205   Test loss: 1.669024   Train accuracy 0.750000   Test accuracy is 0.526786
# Epoch: 131   Train loss: 0.549773   Test loss: 1.714697   Train accuracy 0.794118   Test accuracy is 0.482143
# Epoch: 132   Train loss: 0.589614   Test loss: 1.721730   Train accuracy 0.750000   Test accuracy is 0.517857
# Epoch: 133   Train loss: 0.550323   Test loss: 2.107273   Train accuracy 0.794118   Test accuracy is 0.482143
# Epoch: 134   Train loss: 0.492221   Test loss: 1.800490   Train accuracy 0.808824   Test accuracy is 0.544643
# Epoch: 135   Train loss: 0.479690   Test loss: 1.580353   Train accuracy 0.823529   Test accuracy is 0.500000
# Epoch: 136   Train loss: 0.601515   Test loss: 1.449692   Train accuracy 0.750000   Test accuracy is 0.580357
# Epoch: 137   Train loss: 0.850429   Test loss: 1.536411   Train accuracy 0.691176   Test accuracy is 0.589286
# Epoch: 138   Train loss: 0.590132   Test loss: 3.218168   Train accuracy 0.794118   Test accuracy is 0.383929
# Epoch: 139   Train loss: 0.487435   Test loss: 2.142058   Train accuracy 0.779412   Test accuracy is 0.500000
# Epoch: 140   Train loss: 0.563412   Test loss: 1.990347   Train accuracy 0.794118   Test accuracy is 0.437500
# Epoch: 141   Train loss: 0.627643   Test loss: 2.022703   Train accuracy 0.720588   Test accuracy is 0.517857
# Epoch: 142   Train loss: 0.466791   Test loss: 1.463376   Train accuracy 0.779412   Test accuracy is 0.535714
# Epoch: 143   Train loss: 0.718066   Test loss: 1.729985   Train accuracy 0.705882   Test accuracy is 0.571429
# Epoch: 144   Train loss: 0.494737   Test loss: 1.669090   Train accuracy 0.808824   Test accuracy is 0.598214
# Epoch: 145   Train loss: 0.572839   Test loss: 1.521536   Train accuracy 0.808824   Test accuracy is 0.571429
# Epoch: 146   Train loss: 0.726092   Test loss: 1.870994   Train accuracy 0.691176   Test accuracy is 0.491071
# Epoch: 147   Train loss: 0.624007   Test loss: 1.865300   Train accuracy 0.735294   Test accuracy is 0.455357
# Epoch: 148   Train loss: 0.561915   Test loss: 2.587195   Train accuracy 0.764706   Test accuracy is 0.500000
# Epoch: 149   Train loss: 0.530891   Test loss: 1.675293   Train accuracy 0.823529   Test accuracy is 0.544643
# The average accuracy is: 0.44779761904761917
# The best accuracy is: 0.5982142857142857
# THE BEST ACCURACY IS 0.5982142857142857
# subject 2 duration: 0:09:20.105769
# seed is 679
# Subject 3
# Epoch: 0   Train loss: 1.387316   Test loss: 1.377029   Train accuracy 0.264706   Test accuracy is 0.303571
# Epoch: 1   Train loss: 1.406298   Test loss: 1.326449   Train accuracy 0.191176   Test accuracy is 0.446429
# Epoch: 2   Train loss: 1.223597   Test loss: 1.208745   Train accuracy 0.441176   Test accuracy is 0.455357
# Epoch: 3   Train loss: 0.984702   Test loss: 1.402178   Train accuracy 0.529412   Test accuracy is 0.428571
# Epoch: 4   Train loss: 0.913866   Test loss: 1.144809   Train accuracy 0.514706   Test accuracy is 0.517857
# Epoch: 5   Train loss: 0.841669   Test loss: 1.018468   Train accuracy 0.647059   Test accuracy is 0.535714
# Epoch: 6   Train loss: 0.777491   Test loss: 1.085760   Train accuracy 0.676471   Test accuracy is 0.526786
# Epoch: 7   Train loss: 0.801584   Test loss: 1.038533   Train accuracy 0.676471   Test accuracy is 0.589286
# Epoch: 8   Train loss: 0.857307   Test loss: 1.070161   Train accuracy 0.632353   Test accuracy is 0.589286
# Epoch: 9   Train loss: 0.686354   Test loss: 1.228513   Train accuracy 0.720588   Test accuracy is 0.553571
# Epoch: 10   Train loss: 0.716794   Test loss: 0.923163   Train accuracy 0.691176   Test accuracy is 0.616071
# Epoch: 11   Train loss: 0.642402   Test loss: 1.041857   Train accuracy 0.735294   Test accuracy is 0.607143
# Epoch: 12   Train loss: 0.701264   Test loss: 0.832477   Train accuracy 0.750000   Test accuracy is 0.678571
# Epoch: 13   Train loss: 0.455286   Test loss: 0.674856   Train accuracy 0.808824   Test accuracy is 0.723214
# Epoch: 14   Train loss: 0.437816   Test loss: 0.940392   Train accuracy 0.838235   Test accuracy is 0.678571
# Epoch: 15   Train loss: 0.574344   Test loss: 0.898058   Train accuracy 0.764706   Test accuracy is 0.678571
# Epoch: 16   Train loss: 0.668510   Test loss: 0.860558   Train accuracy 0.720588   Test accuracy is 0.705357
# Epoch: 17   Train loss: 0.415117   Test loss: 0.816042   Train accuracy 0.808824   Test accuracy is 0.723214
# Epoch: 18   Train loss: 0.346731   Test loss: 1.110391   Train accuracy 0.882353   Test accuracy is 0.651786
# Epoch: 19   Train loss: 0.500636   Test loss: 1.231861   Train accuracy 0.764706   Test accuracy is 0.642857
# Epoch: 20   Train loss: 0.498035   Test loss: 0.896359   Train accuracy 0.838235   Test accuracy is 0.714286
# Epoch: 21   Train loss: 0.457118   Test loss: 0.703975   Train accuracy 0.808824   Test accuracy is 0.776786
# Epoch: 22   Train loss: 0.324037   Test loss: 0.543534   Train accuracy 0.852941   Test accuracy is 0.785714
# Epoch: 23   Train loss: 0.405935   Test loss: 0.711423   Train accuracy 0.867647   Test accuracy is 0.794643
# Epoch: 24   Train loss: 0.499455   Test loss: 0.941464   Train accuracy 0.867647   Test accuracy is 0.758929
# Epoch: 25   Train loss: 0.358811   Test loss: 0.962640   Train accuracy 0.897059   Test accuracy is 0.767857
# Epoch: 26   Train loss: 0.698696   Test loss: 1.418040   Train accuracy 0.764706   Test accuracy is 0.723214
# Epoch: 27   Train loss: 0.188446   Test loss: 0.767255   Train accuracy 0.941176   Test accuracy is 0.776786
# Epoch: 28   Train loss: 0.419640   Test loss: 1.034981   Train accuracy 0.852941   Test accuracy is 0.758929
# Epoch: 29   Train loss: 0.342291   Test loss: 0.479419   Train accuracy 0.838235   Test accuracy is 0.866071
# Epoch: 30   Train loss: 0.323580   Test loss: 1.037784   Train accuracy 0.882353   Test accuracy is 0.750000
# Epoch: 31   Train loss: 0.319133   Test loss: 0.667972   Train accuracy 0.897059   Test accuracy is 0.848214
# Epoch: 32   Train loss: 0.388165   Test loss: 1.061369   Train accuracy 0.867647   Test accuracy is 0.723214
# Epoch: 33   Train loss: 0.320632   Test loss: 0.529210   Train accuracy 0.867647   Test accuracy is 0.839286
# Epoch: 34   Train loss: 0.324744   Test loss: 0.782516   Train accuracy 0.897059   Test accuracy is 0.750000
# Epoch: 35   Train loss: 0.300741   Test loss: 0.524052   Train accuracy 0.882353   Test accuracy is 0.857143
# Epoch: 36   Train loss: 0.200908   Test loss: 0.920350   Train accuracy 0.926471   Test accuracy is 0.785714
# Epoch: 37   Train loss: 0.336689   Test loss: 0.814968   Train accuracy 0.838235   Test accuracy is 0.794643
# Epoch: 38   Train loss: 0.384487   Test loss: 0.795090   Train accuracy 0.897059   Test accuracy is 0.830357
# Epoch: 39   Train loss: 0.202838   Test loss: 0.495013   Train accuracy 0.926471   Test accuracy is 0.848214
# Epoch: 40   Train loss: 0.158400   Test loss: 0.691187   Train accuracy 0.926471   Test accuracy is 0.821429
# Epoch: 41   Train loss: 0.371291   Test loss: 0.716069   Train accuracy 0.867647   Test accuracy is 0.821429
# Epoch: 42   Train loss: 0.368268   Test loss: 0.943743   Train accuracy 0.882353   Test accuracy is 0.812500
# Epoch: 43   Train loss: 0.248700   Test loss: 0.554897   Train accuracy 0.941176   Test accuracy is 0.883929
# Epoch: 44   Train loss: 0.247197   Test loss: 0.374499   Train accuracy 0.926471   Test accuracy is 0.910714
# Epoch: 45   Train loss: 0.290401   Test loss: 0.540568   Train accuracy 0.882353   Test accuracy is 0.866071
# Epoch: 46   Train loss: 0.324113   Test loss: 1.160381   Train accuracy 0.911765   Test accuracy is 0.767857
# Epoch: 47   Train loss: 0.294409   Test loss: 0.872477   Train accuracy 0.897059   Test accuracy is 0.812500
# Epoch: 48   Train loss: 0.200321   Test loss: 0.540271   Train accuracy 0.911765   Test accuracy is 0.848214
# Epoch: 49   Train loss: 0.180058   Test loss: 0.594536   Train accuracy 0.911765   Test accuracy is 0.875000
# Epoch: 50   Train loss: 0.318096   Test loss: 0.362778   Train accuracy 0.897059   Test accuracy is 0.892857
# Epoch: 51   Train loss: 0.158260   Test loss: 1.041206   Train accuracy 0.941176   Test accuracy is 0.830357
# Epoch: 52   Train loss: 0.287210   Test loss: 0.997430   Train accuracy 0.867647   Test accuracy is 0.785714
# Epoch: 53   Train loss: 0.222032   Test loss: 0.480542   Train accuracy 0.926471   Test accuracy is 0.875000
# Epoch: 54   Train loss: 0.268720   Test loss: 1.363697   Train accuracy 0.911765   Test accuracy is 0.758929
# Epoch: 55   Train loss: 0.257427   Test loss: 0.575750   Train accuracy 0.897059   Test accuracy is 0.857143
# Epoch: 56   Train loss: 0.323436   Test loss: 0.664757   Train accuracy 0.882353   Test accuracy is 0.830357
# Epoch: 57   Train loss: 0.343148   Test loss: 0.844691   Train accuracy 0.867647   Test accuracy is 0.803571
# Epoch: 58   Train loss: 0.135234   Test loss: 0.791910   Train accuracy 0.941176   Test accuracy is 0.839286
# Epoch: 59   Train loss: 0.239697   Test loss: 0.494744   Train accuracy 0.941176   Test accuracy is 0.830357
# Epoch: 60   Train loss: 0.254041   Test loss: 0.621227   Train accuracy 0.897059   Test accuracy is 0.830357
# Epoch: 61   Train loss: 0.255104   Test loss: 1.051268   Train accuracy 0.911765   Test accuracy is 0.767857
# Epoch: 62   Train loss: 0.415670   Test loss: 0.746155   Train accuracy 0.838235   Test accuracy is 0.866071
# Epoch: 63   Train loss: 0.291673   Test loss: 0.776935   Train accuracy 0.882353   Test accuracy is 0.812500
# Epoch: 64   Train loss: 0.343671   Test loss: 0.596064   Train accuracy 0.882353   Test accuracy is 0.857143
# Epoch: 65   Train loss: 0.206576   Test loss: 0.404513   Train accuracy 0.941176   Test accuracy is 0.910714
# Epoch: 66   Train loss: 0.355904   Test loss: 0.674937   Train accuracy 0.882353   Test accuracy is 0.866071
# Epoch: 67   Train loss: 0.195999   Test loss: 0.793306   Train accuracy 0.911765   Test accuracy is 0.857143
# Epoch: 68   Train loss: 0.260883   Test loss: 0.632561   Train accuracy 0.897059   Test accuracy is 0.812500
# Epoch: 69   Train loss: 0.232663   Test loss: 0.521655   Train accuracy 0.911765   Test accuracy is 0.875000
# Epoch: 70   Train loss: 0.148362   Test loss: 0.405425   Train accuracy 0.955882   Test accuracy is 0.901786
# Epoch: 71   Train loss: 0.202011   Test loss: 0.432024   Train accuracy 0.882353   Test accuracy is 0.883929
# Epoch: 72   Train loss: 0.200934   Test loss: 0.479809   Train accuracy 0.911765   Test accuracy is 0.857143
# Epoch: 73   Train loss: 0.232451   Test loss: 0.610047   Train accuracy 0.926471   Test accuracy is 0.866071
# Epoch: 74   Train loss: 0.108532   Test loss: 0.619531   Train accuracy 0.985294   Test accuracy is 0.875000
# Epoch: 75   Train loss: 0.220497   Test loss: 0.625054   Train accuracy 0.897059   Test accuracy is 0.821429
# Epoch: 76   Train loss: 0.236313   Test loss: 0.460543   Train accuracy 0.926471   Test accuracy is 0.901786
# Epoch: 77   Train loss: 0.280741   Test loss: 0.416671   Train accuracy 0.911765   Test accuracy is 0.883929
# Epoch: 78   Train loss: 0.194389   Test loss: 0.405693   Train accuracy 0.897059   Test accuracy is 0.910714
# Epoch: 79   Train loss: 0.298826   Test loss: 0.587795   Train accuracy 0.882353   Test accuracy is 0.883929
# Epoch: 80   Train loss: 0.139973   Test loss: 0.949215   Train accuracy 0.970588   Test accuracy is 0.785714
# Epoch: 81   Train loss: 0.202123   Test loss: 0.719883   Train accuracy 0.926471   Test accuracy is 0.839286
# Epoch: 82   Train loss: 0.270909   Test loss: 0.565606   Train accuracy 0.911765   Test accuracy is 0.883929
# Epoch: 83   Train loss: 0.104001   Test loss: 0.938007   Train accuracy 0.985294   Test accuracy is 0.803571
# Epoch: 84   Train loss: 0.158253   Test loss: 0.507107   Train accuracy 0.926471   Test accuracy is 0.839286
# Epoch: 85   Train loss: 0.198275   Test loss: 0.757761   Train accuracy 0.911765   Test accuracy is 0.857143
# Epoch: 86   Train loss: 0.190844   Test loss: 0.560860   Train accuracy 0.926471   Test accuracy is 0.839286
# Epoch: 87   Train loss: 0.086093   Test loss: 0.394383   Train accuracy 0.985294   Test accuracy is 0.928571
# Epoch: 88   Train loss: 0.286287   Test loss: 0.632273   Train accuracy 0.911765   Test accuracy is 0.866071
# Epoch: 89   Train loss: 0.086602   Test loss: 0.665538   Train accuracy 0.955882   Test accuracy is 0.830357
# Epoch: 90   Train loss: 0.136647   Test loss: 0.355529   Train accuracy 0.941176   Test accuracy is 0.919643
# Epoch: 91   Train loss: 0.216112   Test loss: 0.533432   Train accuracy 0.911765   Test accuracy is 0.875000
# Epoch: 92   Train loss: 0.320006   Test loss: 0.440689   Train accuracy 0.882353   Test accuracy is 0.892857
# Epoch: 93   Train loss: 0.270294   Test loss: 0.768482   Train accuracy 0.955882   Test accuracy is 0.848214
# Epoch: 94   Train loss: 0.122609   Test loss: 0.397909   Train accuracy 0.955882   Test accuracy is 0.910714
# Epoch: 95   Train loss: 0.331678   Test loss: 0.588745   Train accuracy 0.897059   Test accuracy is 0.848214
# Epoch: 96   Train loss: 0.083820   Test loss: 0.716350   Train accuracy 0.970588   Test accuracy is 0.839286
# Epoch: 97   Train loss: 0.235939   Test loss: 0.436894   Train accuracy 0.926471   Test accuracy is 0.919643
# Epoch: 98   Train loss: 0.444123   Test loss: 0.628088   Train accuracy 0.882353   Test accuracy is 0.848214
# Epoch: 99   Train loss: 0.294522   Test loss: 0.384311   Train accuracy 0.911765   Test accuracy is 0.919643
# Epoch: 100   Train loss: 0.243349   Test loss: 0.419685   Train accuracy 0.926471   Test accuracy is 0.857143
# Epoch: 101   Train loss: 0.285366   Test loss: 0.585276   Train accuracy 0.882353   Test accuracy is 0.848214
# Epoch: 102   Train loss: 0.124761   Test loss: 0.565568   Train accuracy 0.955882   Test accuracy is 0.892857
# Epoch: 103   Train loss: 0.126394   Test loss: 0.627668   Train accuracy 0.941176   Test accuracy is 0.901786
# Epoch: 104   Train loss: 0.153042   Test loss: 0.556194   Train accuracy 0.941176   Test accuracy is 0.892857
# Epoch: 105   Train loss: 0.169520   Test loss: 0.476992   Train accuracy 0.941176   Test accuracy is 0.910714
# Epoch: 106   Train loss: 0.129656   Test loss: 0.436045   Train accuracy 0.941176   Test accuracy is 0.901786
# Epoch: 107   Train loss: 0.277879   Test loss: 0.324223   Train accuracy 0.911765   Test accuracy is 0.919643
# Epoch: 108   Train loss: 0.285786   Test loss: 0.465036   Train accuracy 0.897059   Test accuracy is 0.910714
# Epoch: 109   Train loss: 0.168400   Test loss: 0.554331   Train accuracy 0.941176   Test accuracy is 0.901786
# Epoch: 110   Train loss: 0.154778   Test loss: 0.673442   Train accuracy 0.926471   Test accuracy is 0.785714
# Epoch: 111   Train loss: 0.344412   Test loss: 1.139483   Train accuracy 0.882353   Test accuracy is 0.767857
# Epoch: 112   Train loss: 0.274461   Test loss: 0.645028   Train accuracy 0.926471   Test accuracy is 0.839286
# Epoch: 113   Train loss: 0.130125   Test loss: 0.329680   Train accuracy 0.941176   Test accuracy is 0.919643
# Epoch: 114   Train loss: 0.166335   Test loss: 0.394979   Train accuracy 0.926471   Test accuracy is 0.901786
# Epoch: 115   Train loss: 0.174603   Test loss: 0.383354   Train accuracy 0.941176   Test accuracy is 0.883929
# Epoch: 116   Train loss: 0.210729   Test loss: 0.628722   Train accuracy 0.926471   Test accuracy is 0.803571
# Epoch: 117   Train loss: 0.078409   Test loss: 0.362976   Train accuracy 0.970588   Test accuracy is 0.901786
# Epoch: 118   Train loss: 0.263803   Test loss: 0.946286   Train accuracy 0.911765   Test accuracy is 0.758929
# Epoch: 119   Train loss: 0.135994   Test loss: 0.511295   Train accuracy 0.955882   Test accuracy is 0.875000
# Epoch: 120   Train loss: 0.196197   Test loss: 0.415670   Train accuracy 0.911765   Test accuracy is 0.892857
# Epoch: 121   Train loss: 0.171799   Test loss: 0.414963   Train accuracy 0.970588   Test accuracy is 0.910714
# Epoch: 122   Train loss: 0.133917   Test loss: 0.478035   Train accuracy 0.955882   Test accuracy is 0.848214
# Epoch: 123   Train loss: 0.125658   Test loss: 0.422406   Train accuracy 0.955882   Test accuracy is 0.919643
# Epoch: 124   Train loss: 0.135729   Test loss: 1.224795   Train accuracy 0.955882   Test accuracy is 0.758929
# Epoch: 125   Train loss: 0.227811   Test loss: 0.729820   Train accuracy 0.926471   Test accuracy is 0.812500
# Epoch: 126   Train loss: 0.205264   Test loss: 1.089196   Train accuracy 0.926471   Test accuracy is 0.776786
# Epoch: 127   Train loss: 0.113636   Test loss: 0.467665   Train accuracy 0.955882   Test accuracy is 0.901786
# Epoch: 128   Train loss: 0.168953   Test loss: 0.809149   Train accuracy 0.941176   Test accuracy is 0.839286
# Epoch: 129   Train loss: 0.207123   Test loss: 0.794352   Train accuracy 0.926471   Test accuracy is 0.821429
# Epoch: 130   Train loss: 0.100039   Test loss: 1.025715   Train accuracy 0.970588   Test accuracy is 0.803571
# Epoch: 131   Train loss: 0.151474   Test loss: 0.273677   Train accuracy 0.970588   Test accuracy is 0.946429
# Epoch: 132   Train loss: 0.291885   Test loss: 0.409774   Train accuracy 0.911765   Test accuracy is 0.928571
# Epoch: 133   Train loss: 0.197220   Test loss: 0.340753   Train accuracy 0.911765   Test accuracy is 0.919643
# Epoch: 134   Train loss: 0.189284   Test loss: 0.630536   Train accuracy 0.897059   Test accuracy is 0.839286
# ...
# Epoch: 6   Train loss: 0.878580   Test loss: 1.348702   Train accuracy 0.632353   Test accuracy is 0.491071
# Epoch: 7   Train loss: 0.862806   Test loss: 1.458759   Train accuracy 0.602941   Test accuracy is 0.508929
# Epoch: 8   Train loss: 0.885834   Test loss: 1.736156   Train accuracy 0.573529   Test accuracy is 0.473214
# Epoch: 9   Train loss: 0.908809   Test loss: 2.023550   Train accuracy 0.602941   Test accuracy is 0.437500
# Epoch: 10   Train loss: 0.822465   Test loss: 1.652353   Train accuracy 0.602941   Test accuracy is 0.500000
# Epoch: 11   Train loss: 0.684268   Test loss: 1.333530   Train accuracy 0.720588   Test accuracy is 0.571429
# Epoch: 12   Train loss: 0.704871   Test loss: 1.087581   Train accuracy 0.750000   Test accuracy is 0.589286
# Epoch: 13   Train loss: 0.708650   Test loss: 0.808464   Train accuracy 0.720588   Test accuracy is 0.625000
# Epoch: 14   Train loss: 0.607832   Test loss: 0.851995   Train accuracy 0.764706   Test accuracy is 0.669643
# Epoch: 15   Train loss: 0.808887   Test loss: 0.916087   Train accuracy 0.691176   Test accuracy is 0.651786
# Epoch: 16   Train loss: 0.693284   Test loss: 1.152292   Train accuracy 0.720588   Test accuracy is 0.660714
# Epoch: 17   Train loss: 0.686460   Test loss: 0.912992   Train accuracy 0.779412   Test accuracy is 0.678571
# Epoch: 18   Train loss: 0.530698   Test loss: 1.228572   Train accuracy 0.808824   Test accuracy is 0.642857
# Epoch: 19   Train loss: 0.567058   Test loss: 1.024070   Train accuracy 0.794118   Test accuracy is 0.696429
# Epoch: 20   Train loss: 0.477461   Test loss: 1.485619   Train accuracy 0.808824   Test accuracy is 0.642857
# Epoch: 21   Train loss: 0.360168   Test loss: 0.659961   Train accuracy 0.838235   Test accuracy is 0.767857
# Epoch: 22   Train loss: 0.612996   Test loss: 1.449706   Train accuracy 0.750000   Test accuracy is 0.589286
# Epoch: 23   Train loss: 0.477018   Test loss: 1.340726   Train accuracy 0.823529   Test accuracy is 0.616071
# Epoch: 24   Train loss: 0.503373   Test loss: 1.448425   Train accuracy 0.823529   Test accuracy is 0.678571
# Epoch: 25   Train loss: 0.523394   Test loss: 0.706849   Train accuracy 0.779412   Test accuracy is 0.776786
# Epoch: 26   Train loss: 0.576270   Test loss: 1.002657   Train accuracy 0.794118   Test accuracy is 0.669643
# Epoch: 27   Train loss: 0.420456   Test loss: 0.747446   Train accuracy 0.911765   Test accuracy is 0.750000
# Epoch: 28   Train loss: 0.582151   Test loss: 1.321898   Train accuracy 0.808824   Test accuracy is 0.607143
# Epoch: 29   Train loss: 0.462460   Test loss: 0.691554   Train accuracy 0.823529   Test accuracy is 0.794643
# Epoch: 30   Train loss: 0.457150   Test loss: 0.663840   Train accuracy 0.808824   Test accuracy is 0.785714
# Epoch: 31   Train loss: 0.261985   Test loss: 1.309689   Train accuracy 0.911765   Test accuracy is 0.687500
# Epoch: 32   Train loss: 0.417386   Test loss: 0.931749   Train accuracy 0.838235   Test accuracy is 0.723214
# Epoch: 33   Train loss: 0.417067   Test loss: 1.040671   Train accuracy 0.852941   Test accuracy is 0.687500
# Epoch: 34   Train loss: 0.427278   Test loss: 0.966172   Train accuracy 0.794118   Test accuracy is 0.741071
# Epoch: 35   Train loss: 0.312755   Test loss: 1.464056   Train accuracy 0.897059   Test accuracy is 0.660714
# Epoch: 36   Train loss: 0.431500   Test loss: 1.287332   Train accuracy 0.867647   Test accuracy is 0.696429
# Epoch: 37   Train loss: 0.318117   Test loss: 1.473743   Train accuracy 0.882353   Test accuracy is 0.678571
# Epoch: 38   Train loss: 0.319421   Test loss: 1.368433   Train accuracy 0.911765   Test accuracy is 0.678571
# Epoch: 39   Train loss: 0.402328   Test loss: 0.776044   Train accuracy 0.823529   Test accuracy is 0.758929
# Epoch: 40   Train loss: 0.422660   Test loss: 1.187365   Train accuracy 0.852941   Test accuracy is 0.714286
# Epoch: 41   Train loss: 0.237104   Test loss: 0.864651   Train accuracy 0.941176   Test accuracy is 0.785714
# Epoch: 42   Train loss: 0.317022   Test loss: 1.332935   Train accuracy 0.926471   Test accuracy is 0.705357
# Epoch: 43   Train loss: 0.305410   Test loss: 1.640817   Train accuracy 0.897059   Test accuracy is 0.678571
# Epoch: 44   Train loss: 0.468324   Test loss: 1.337420   Train accuracy 0.808824   Test accuracy is 0.669643
# Epoch: 45   Train loss: 0.323509   Test loss: 0.853603   Train accuracy 0.823529   Test accuracy is 0.767857
# Epoch: 46   Train loss: 0.489697   Test loss: 1.064098   Train accuracy 0.867647   Test accuracy is 0.723214
# Epoch: 47   Train loss: 0.581447   Test loss: 1.096126   Train accuracy 0.794118   Test accuracy is 0.714286
# Epoch: 48   Train loss: 0.447221   Test loss: 1.006899   Train accuracy 0.838235   Test accuracy is 0.714286
# Epoch: 49   Train loss: 0.390864   Test loss: 0.951364   Train accuracy 0.882353   Test accuracy is 0.732143
# Epoch: 50   Train loss: 0.321352   Test loss: 0.910287   Train accuracy 0.941176   Test accuracy is 0.741071
# Epoch: 51   Train loss: 0.299162   Test loss: 1.040978   Train accuracy 0.867647   Test accuracy is 0.696429
# Epoch: 52   Train loss: 0.303962   Test loss: 0.955927   Train accuracy 0.867647   Test accuracy is 0.732143
# Epoch: 53   Train loss: 0.340918   Test loss: 1.052754   Train accuracy 0.897059   Test accuracy is 0.732143
# Epoch: 54   Train loss: 0.382798   Test loss: 1.005412   Train accuracy 0.852941   Test accuracy is 0.732143
# Epoch: 55   Train loss: 0.410001   Test loss: 1.180899   Train accuracy 0.867647   Test accuracy is 0.687500
# Epoch: 56   Train loss: 0.293957   Test loss: 0.973223   Train accuracy 0.926471   Test accuracy is 0.714286
# Epoch: 57   Train loss: 0.491274   Test loss: 0.700542   Train accuracy 0.838235   Test accuracy is 0.794643
# Epoch: 58   Train loss: 0.416819   Test loss: 0.877746   Train accuracy 0.867647   Test accuracy is 0.767857
# Epoch: 59   Train loss: 0.337568   Test loss: 0.896933   Train accuracy 0.897059   Test accuracy is 0.758929
# Epoch: 60   Train loss: 0.237735   Test loss: 0.972025   Train accuracy 0.926471   Test accuracy is 0.758929
# Epoch: 61   Train loss: 0.281380   Test loss: 0.794651   Train accuracy 0.882353   Test accuracy is 0.785714
# Epoch: 62   Train loss: 0.265612   Test loss: 0.797944   Train accuracy 0.897059   Test accuracy is 0.758929
# Epoch: 63   Train loss: 0.324241   Test loss: 0.935524   Train accuracy 0.897059   Test accuracy is 0.776786
# Epoch: 64   Train loss: 0.308477   Test loss: 1.024228   Train accuracy 0.897059   Test accuracy is 0.741071
# Epoch: 65   Train loss: 0.224826   Test loss: 1.156758   Train accuracy 0.897059   Test accuracy is 0.705357
# Epoch: 66   Train loss: 0.362337   Test loss: 1.145248   Train accuracy 0.897059   Test accuracy is 0.741071
# Epoch: 67   Train loss: 0.248279   Test loss: 0.917241   Train accuracy 0.926471   Test accuracy is 0.750000
# Epoch: 68   Train loss: 0.218325   Test loss: 0.818342   Train accuracy 0.911765   Test accuracy is 0.776786
# Epoch: 69   Train loss: 0.291784   Test loss: 1.001450   Train accuracy 0.911765   Test accuracy is 0.741071
# Epoch: 70   Train loss: 0.368551   Test loss: 0.714722   Train accuracy 0.897059   Test accuracy is 0.812500
# Epoch: 71   Train loss: 0.364109   Test loss: 0.813239   Train accuracy 0.897059   Test accuracy is 0.776786
# Epoch: 72   Train loss: 0.206808   Test loss: 0.829781   Train accuracy 0.911765   Test accuracy is 0.803571
# Epoch: 73   Train loss: 0.459890   Test loss: 1.012454   Train accuracy 0.852941   Test accuracy is 0.776786
# Epoch: 74   Train loss: 0.275506   Test loss: 1.233964   Train accuracy 0.897059   Test accuracy is 0.723214
# Epoch: 75   Train loss: 0.242173   Test loss: 1.212321   Train accuracy 0.897059   Test accuracy is 0.741071
# Epoch: 76   Train loss: 0.254195   Test loss: 0.949922   Train accuracy 0.911765   Test accuracy is 0.785714
# Epoch: 77   Train loss: 0.265707   Test loss: 1.490372   Train accuracy 0.882353   Test accuracy is 0.705357
# Epoch: 78   Train loss: 0.245552   Test loss: 1.081460   Train accuracy 0.941176   Test accuracy is 0.767857
# Epoch: 79   Train loss: 0.320666   Test loss: 1.070356   Train accuracy 0.897059   Test accuracy is 0.767857
# Epoch: 80   Train loss: 0.339898   Test loss: 1.011405   Train accuracy 0.882353   Test accuracy is 0.794643
# Epoch: 81   Train loss: 0.299552   Test loss: 1.622023   Train accuracy 0.941176   Test accuracy is 0.616071
# Epoch: 82   Train loss: 0.371457   Test loss: 1.046941   Train accuracy 0.867647   Test accuracy is 0.758929
# Epoch: 83   Train loss: 0.237681   Test loss: 0.970213   Train accuracy 0.955882   Test accuracy is 0.785714
# Epoch: 84   Train loss: 0.197142   Test loss: 1.107777   Train accuracy 0.955882   Test accuracy is 0.741071
# Epoch: 85   Train loss: 0.302978   Test loss: 0.837413   Train accuracy 0.911765   Test accuracy is 0.776786
# Epoch: 86   Train loss: 0.341628   Test loss: 0.723621   Train accuracy 0.882353   Test accuracy is 0.821429
# Epoch: 87   Train loss: 0.211081   Test loss: 0.649801   Train accuracy 0.897059   Test accuracy is 0.821429
# Epoch: 88   Train loss: 0.298728   Test loss: 1.002816   Train accuracy 0.867647   Test accuracy is 0.776786
# Epoch: 89   Train loss: 0.220352   Test loss: 0.704576   Train accuracy 0.926471   Test accuracy is 0.785714
# Epoch: 90   Train loss: 0.244029   Test loss: 0.815085   Train accuracy 0.911765   Test accuracy is 0.785714
# Epoch: 91   Train loss: 0.245821   Test loss: 1.146260   Train accuracy 0.882353   Test accuracy is 0.776786
# Epoch: 92   Train loss: 0.199976   Test loss: 0.784112   Train accuracy 0.941176   Test accuracy is 0.803571
# Epoch: 93   Train loss: 0.253127   Test loss: 0.934980   Train accuracy 0.941176   Test accuracy is 0.785714
# Epoch: 94   Train loss: 0.281381   Test loss: 0.787316   Train accuracy 0.911765   Test accuracy is 0.830357
# Epoch: 95   Train loss: 0.295327   Test loss: 1.040192   Train accuracy 0.926471   Test accuracy is 0.732143
# Epoch: 96   Train loss: 0.145470   Test loss: 0.968759   Train accuracy 0.955882   Test accuracy is 0.794643
# Epoch: 97   Train loss: 0.237565   Test loss: 1.039914   Train accuracy 0.926471   Test accuracy is 0.785714
# Epoch: 98   Train loss: 0.522276   Test loss: 0.754638   Train accuracy 0.852941   Test accuracy is 0.821429
# Epoch: 99   Train loss: 0.177264   Test loss: 0.978508   Train accuracy 0.970588   Test accuracy is 0.785714
# Epoch: 100   Train loss: 0.171017   Test loss: 1.112542   Train accuracy 0.926471   Test accuracy is 0.785714
# Epoch: 101   Train loss: 0.173072   Test loss: 0.872142   Train accuracy 0.926471   Test accuracy is 0.803571
# Epoch: 102   Train loss: 0.184529   Test loss: 0.852432   Train accuracy 0.897059   Test accuracy is 0.794643
# Epoch: 103   Train loss: 0.122844   Test loss: 0.943584   Train accuracy 0.985294   Test accuracy is 0.803571
# Epoch: 104   Train loss: 0.180356   Test loss: 1.152694   Train accuracy 0.955882   Test accuracy is 0.776786
# Epoch: 105   Train loss: 0.213376   Test loss: 1.392272   Train accuracy 0.941176   Test accuracy is 0.758929
# Epoch: 106   Train loss: 0.206416   Test loss: 0.856744   Train accuracy 0.941176   Test accuracy is 0.794643
# Epoch: 107   Train loss: 0.245771   Test loss: 0.963984   Train accuracy 0.911765   Test accuracy is 0.812500
# Epoch: 108   Train loss: 0.211387   Test loss: 0.998429   Train accuracy 0.911765   Test accuracy is 0.785714
# Epoch: 109   Train loss: 0.238452   Test loss: 0.964116   Train accuracy 0.941176   Test accuracy is 0.785714
# Epoch: 110   Train loss: 0.212734   Test loss: 1.090814   Train accuracy 0.926471   Test accuracy is 0.767857
# Epoch: 111   Train loss: 0.381775   Test loss: 1.328207   Train accuracy 0.882353   Test accuracy is 0.776786
# Epoch: 112   Train loss: 0.070359   Test loss: 1.401171   Train accuracy 0.970588   Test accuracy is 0.750000
# Epoch: 113   Train loss: 0.278326   Test loss: 0.986759   Train accuracy 0.897059   Test accuracy is 0.785714
# Epoch: 114   Train loss: 0.358784   Test loss: 1.257495   Train accuracy 0.852941   Test accuracy is 0.750000
# Epoch: 115   Train loss: 0.262070   Test loss: 0.925414   Train accuracy 0.941176   Test accuracy is 0.803571
# Epoch: 116   Train loss: 0.117595   Test loss: 0.813762   Train accuracy 0.970588   Test accuracy is 0.812500
# Epoch: 117   Train loss: 0.129875   Test loss: 1.615818   Train accuracy 0.941176   Test accuracy is 0.723214
# Epoch: 118   Train loss: 0.159586   Test loss: 0.807151   Train accuracy 0.970588   Test accuracy is 0.821429
# Epoch: 119   Train loss: 0.140625   Test loss: 1.022815   Train accuracy 0.970588   Test accuracy is 0.803571
# Epoch: 120   Train loss: 0.161145   Test loss: 0.918113   Train accuracy 0.955882   Test accuracy is 0.803571
# Epoch: 121   Train loss: 0.104178   Test loss: 1.394602   Train accuracy 0.955882   Test accuracy is 0.741071
# Epoch: 122   Train loss: 0.174596   Test loss: 1.149427   Train accuracy 0.926471   Test accuracy is 0.803571
# Epoch: 123   Train loss: 0.274113   Test loss: 0.839326   Train accuracy 0.926471   Test accuracy is 0.839286
# Epoch: 124   Train loss: 0.052366   Test loss: 1.096510   Train accuracy 1.000000   Test accuracy is 0.803571
# Epoch: 125   Train loss: 0.247725   Test loss: 0.806384   Train accuracy 0.897059   Test accuracy is 0.857143
# Epoch: 126   Train loss: 0.293600   Test loss: 0.853056   Train accuracy 0.897059   Test accuracy is 0.830357
# Epoch: 127   Train loss: 0.181878   Test loss: 0.966815   Train accuracy 0.955882   Test accuracy is 0.803571
# Epoch: 128   Train loss: 0.234348   Test loss: 0.877557   Train accuracy 0.911765   Test accuracy is 0.821429
# Epoch: 129   Train loss: 0.146391   Test loss: 0.806329   Train accuracy 0.941176   Test accuracy is 0.848214
# Epoch: 130   Train loss: 0.265838   Test loss: 0.848838   Train accuracy 0.897059   Test accuracy is 0.830357
# Epoch: 131   Train loss: 0.167345   Test loss: 0.993547   Train accuracy 0.955882   Test accuracy is 0.821429
# Epoch: 132   Train loss: 0.190569   Test loss: 1.099661   Train accuracy 0.911765   Test accuracy is 0.794643
# Epoch: 133   Train loss: 0.132183   Test loss: 1.029265   Train accuracy 0.970588   Test accuracy is 0.812500
# Epoch: 134   Train loss: 0.064441   Test loss: 0.905284   Train accuracy 1.000000   Test accuracy is 0.839286
# Epoch: 135   Train loss: 0.270601   Test loss: 1.292013   Train accuracy 0.911765   Test accuracy is 0.785714
# Epoch: 136   Train loss: 0.172965   Test loss: 1.167988   Train accuracy 0.897059   Test accuracy is 0.758929
# Epoch: 137   Train loss: 0.370579   Test loss: 1.520856   Train accuracy 0.867647   Test accuracy is 0.741071
# Epoch: 138   Train loss: 0.135159   Test loss: 0.947540   Train accuracy 0.941176   Test accuracy is 0.839286
# Epoch: 139   Train loss: 0.094135   Test loss: 0.904054   Train accuracy 0.955882   Test accuracy is 0.812500
# Epoch: 140   Train loss: 0.229833   Test loss: 0.906684   Train accuracy 0.911765   Test accuracy is 0.848214
# Epoch: 141   Train loss: 0.224951   Test loss: 1.788388   Train accuracy 0.911765   Test accuracy is 0.705357
# Epoch: 142   Train loss: 0.094934   Test loss: 0.751825   Train accuracy 0.955882   Test accuracy is 0.839286
# Epoch: 143   Train loss: 0.269510   Test loss: 0.683507   Train accuracy 0.867647   Test accuracy is 0.875000
# Epoch: 144   Train loss: 0.165352   Test loss: 0.907568   Train accuracy 0.955882   Test accuracy is 0.803571
# Epoch: 145   Train loss: 0.144925   Test loss: 0.967331   Train accuracy 0.941176   Test accuracy is 0.821429
# Epoch: 146   Train loss: 0.227189   Test loss: 1.245616   Train accuracy 0.911765   Test accuracy is 0.803571
# Epoch: 147   Train loss: 0.189585   Test loss: 1.151736   Train accuracy 0.926471   Test accuracy is 0.803571
# Epoch: 148   Train loss: 0.191648   Test loss: 0.912300   Train accuracy 0.955882   Test accuracy is 0.839286
# Epoch: 149   Train loss: 0.172457   Test loss: 0.822048   Train accuracy 0.926471   Test accuracy is 0.839286
# The average accuracy is: 0.7347023809523812
# The best accuracy is: 0.875
# THE BEST ACCURACY IS 0.875
# subject 9 duration: 0:09:23.448343
# Sat Jun 17 14:40:12 2023

# %%
import shutil

# Specify the source directory where the text files are located
source_directory = '/content/'

# Specify the destination directory in your Google Drive
destination_directory = '/content/drive/MyDrive/result3dconv-conformergraz2'

# Move all text files from the source directory to the destination directory
for file_name in os.listdir(source_directory):
    if file_name.endswith('.txt'):
        file_path = os.path.join(source_directory, file_name)
        shutil.move(file_path, destination_directory)

print("Text files moved to Google Drive successfully.")
# Out:
# Text files moved to Google Drive successfully.
