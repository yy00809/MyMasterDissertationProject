# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import zipfile

# Specify the path to the zip archive
zip_path = '/content/drive/MyDrive/2dmotornorm.zip'

# Specify the directory where you want to extract the files
extract_dir = '/content/'

# Open the zip archive
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # Extract all the contents of the zip archive to the specified directory
    zip_ref.extractall(extract_dir)

print("Folder decompressed successfully.")
# Out:
# Folder decompressed successfully.

# %%
import glob
from google.colab import files
import scipy.io
import numpy as np
# Get a list of .mat files in the current directory
file_list = glob.glob('/content/2dmotornorm/*.mat')

# %%
# not merged
counter = 1

file = open('filenamechange.txt', 'w')


# Close the file

for file_path in file_list:
    file.write(file_path+" to " + str(counter)+"\n")
    mat_data = scipy.io.loadmat(file_path)
    permutation = np.random.permutation(len(mat_data['data']))

    data = mat_data['data'][permutation]
    label = mat_data['label'][0][permutation]

    training = {'data': data[:int(len(data)*0.7)], 'label': label[:int(len(data)*0.7)]}
    testing = {'data': data[int(len(data)*0.7):], 'label': label[int(len(data)*0.7):]}
    scipy.io.savemat('A0'+str(counter)+'T_P.mat', training)
    scipy.io.savemat('A0'+str(counter)+'E_P.mat', testing)
    counter += 1
file.close()

# %%
! pip install einops
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (0.6.1)

# %%
# !pip install torchvision --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.27.1)
# Requirement already satisfied: torch==2.0.1 in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.0.1+cu118)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (8.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.0.1->torchvision) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch==2.0.1->torchvision) (16.0.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.0.1->torchvision) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.0.1->torchvision) (1.3.0)

# %%
import argparse
import os
gpus = [0]
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join(map(str, gpus))
import numpy as np
import math
import glob
import random
import itertools
import datetime
import time
import datetime
import sys
import scipy.io

import torchvision.transforms as transforms
from torchvision.utils import save_image, make_grid

from torch.utils.data import DataLoader
from torch.autograd import Variable
from torchsummary import summary
import torch.autograd as autograd
from torchvision.models import vgg19

import torch.nn as nn
import torch.nn.functional as F
import torch
import torch.nn.init as init

from torch.utils.data import Dataset
from PIL import Image
import torchvision.transforms as transforms
from sklearn.decomposition import PCA

import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt

from torch import nn
from torch import Tensor
from PIL import Image
from torchvision.transforms import Compose, Resize, ToTensor
from einops import rearrange, reduce, repeat
from einops.layers.torch import Rearrange, Reduce
# from common_spatial_pattern import csp

import matplotlib.pyplot as plt
# from torch.utils.tensorboard import SummaryWriter
from torch.backends import cudnn
cudnn.benchmark = False
cudnn.deterministic = True

# %%
# writer = SummaryWriter('./TensorBoardX/')
# data shape (115,64,640)

# Convolution module
# use conv to capture local features, instead of postion embedding.
class PatchEmbedding(nn.Module):
    def __init__(self, emb_size=32):
        # self.patch_size = patch_size
        super().__init__()

        self.shallownet = nn.Sequential(
            nn.Conv2d(1, 32, (1, 20), (1, 1)),
            nn.Conv2d(32, 32, (64, 1), (1, 1)),
            nn.BatchNorm2d(32),
            nn.ELU(),
            nn.AvgPool2d((1, 75), (1, 15)),  # pooling acts as slicing to obtain 'patch' along the time dimension as in ViT
            nn.Dropout(0.5),
        )

        self.projection = nn.Sequential(
            nn.Conv2d(32, emb_size, (1, 1), stride=(1, 1)),  # transpose, conv could enhance fiting ability slightly
            Rearrange('b e (h) (w) -> b (h w) e'),
        )


    def forward(self, x: Tensor) -> Tensor:
        b, _, _, _ = x.shape
        x = self.shallownet(x)
        x = self.projection(x)

        return x


class MultiHeadAttention(nn.Module):
    def __init__(self, emb_size, num_heads, dropout):
        super().__init__()
        self.emb_size = emb_size
        self.num_heads = num_heads
        self.keys = nn.Linear(emb_size, emb_size)
        self.queries = nn.Linear(emb_size, emb_size)
        self.values = nn.Linear(emb_size, emb_size)
        self.att_drop = nn.Dropout(dropout)
        self.projection = nn.Linear(emb_size, emb_size)

    def forward(self, x: Tensor, mask: Tensor = None) -> Tensor:
        queries = rearrange(self.queries(x), "b n (h d) -> b h n d", h=self.num_heads)
        keys = rearrange(self.keys(x), "b n (h d) -> b h n d", h=self.num_heads)
        values = rearrange(self.values(x), "b n (h d) -> b h n d", h=self.num_heads)
        energy = torch.einsum('bhqd, bhkd -> bhqk', queries, keys)
        if mask is not None:
            fill_value = torch.finfo(torch.float32).min
            energy.mask_fill(~mask, fill_value)

        scaling = self.emb_size ** (1 / 2)
        att = F.softmax(energy / scaling, dim=-1)
        att = self.att_drop(att)
        out = torch.einsum('bhal, bhlv -> bhav ', att, values)
        out = rearrange(out, "b h n d -> b n (h d)")
        out = self.projection(out)
        return out


class ResidualAdd(nn.Module):
    def __init__(self, fn):
        super().__init__()
        self.fn = fn

    def forward(self, x, **kwargs):
        res = x
        x = self.fn(x, **kwargs)
        x += res
        return x


class FeedForwardBlock(nn.Sequential):
    def __init__(self, emb_size, expansion, drop_p):
        super().__init__(
            nn.Linear(emb_size, expansion * emb_size),
            nn.GELU(),
            nn.Dropout(drop_p),
            nn.Linear(expansion * emb_size, emb_size),
        )


class GELU(nn.Module):
    def forward(self, input: Tensor) -> Tensor:
        return input*0.5*(1.0+torch.erf(input/math.sqrt(2.0)))


class TransformerEncoderBlock(nn.Sequential):
    def __init__(self,
                 emb_size,
                 num_heads=8,
                 drop_p=0.5,
                 forward_expansion=4,
                 forward_drop_p=0.5):
        super().__init__(
            ResidualAdd(nn.Sequential(
                nn.LayerNorm(emb_size),
                MultiHeadAttention(emb_size, num_heads, drop_p),
                nn.Dropout(drop_p)
            )),
            ResidualAdd(nn.Sequential(
                nn.LayerNorm(emb_size),
                FeedForwardBlock(
                    emb_size, expansion=forward_expansion, drop_p=forward_drop_p),
                nn.Dropout(drop_p)
            )
            ))


class TransformerEncoder(nn.Sequential):
    def __init__(self, depth, emb_size):
        super().__init__(*[TransformerEncoderBlock(emb_size) for _ in range(depth)])


class ClassificationHead(nn.Sequential):
    def __init__(self, emb_size, n_classes):
        super().__init__()

        # global average pooling
        self.clshead = nn.Sequential(
            Reduce('b n e -> b e', reduction='mean'),
            nn.LayerNorm(emb_size),
            nn.Linear(emb_size, n_classes)
        )
        self.fc = nn.Sequential(
            nn.Linear(1184, 256),
            nn.ELU(),
            nn.Dropout(0.5),
            nn.Linear(256, 32),
            nn.ELU(),
            nn.Dropout(0.3),
            nn.Linear(32, 4)
        )

    def forward(self, x):
        x = x.contiguous().view(x.size(0), -1)
        out = self.fc(x)
        return x, out


class Conformer(nn.Sequential):
    def __init__(self, emb_size=32, depth=6, n_classes=4, **kwargs):
        super().__init__(

            PatchEmbedding(emb_size),
            TransformerEncoder(depth, emb_size),
            ClassificationHead(emb_size, n_classes)
        )


class ExP():
    def __init__(self, nsub):
        super(ExP, self).__init__()
        self.batch_size = 36
        #self.batch_size = 12
        self.n_epochs = 150
        self.c_dim = 4
        self.lr = 0.0001
        self.b1 = 0.5
        self.b2 = 0.999
        self.dimension = (190, 50)
        self.nSub = nsub

        self.start_epoch = 0
        self.root = ''

        self.log_write = open("log_subject%d.txt" % self.nSub, "w")


        self.Tensor = torch.cuda.FloatTensor
        self.LongTensor = torch.cuda.LongTensor

        self.criterion_l1 = torch.nn.L1Loss().cuda()
        self.criterion_l2 = torch.nn.MSELoss().cuda()
        self.criterion_cls = torch.nn.CrossEntropyLoss().cuda()

        self.model = Conformer().cuda()
        self.model = nn.DataParallel(self.model, device_ids=[i for i in range(len(gpus))])
        self.model = self.model.cuda()
        # summary(self.model, (1, 22, 1000))


    # Segmentation and Reconstruction (S&R) data augmentation
    def interaug(self, timg, label):
        aug_data = []
        aug_label = []
        for cls4aug in range(4):
            cls_idx = np.where(label == cls4aug + 1)
            tmp_data = timg[cls_idx]
            tmp_data = np.expand_dims(tmp_data, axis=1)
            tmp_label = label[cls_idx]


            tmp_aug_data = np.zeros((int(self.batch_size / 4), 1, 64, 640))
            for ri in range(int(self.batch_size / 4)):
                for rj in range(8):
                    rand_idx = np.random.randint(0, tmp_data.shape[0], 8)
                    tmp_aug_data[ri, :, :, rj * 80:(rj + 1) * 80] = tmp_data[rand_idx[rj], :, :, rj * 80:(rj + 1) * 80]

            aug_data.append(tmp_aug_data)
            aug_label.append(tmp_label[:int(self.batch_size / 4)])
        aug_data = np.concatenate(aug_data)
        aug_label = np.concatenate(aug_label)
        aug_shuffle = np.random.permutation(len(aug_data))
        aug_data = aug_data[aug_shuffle, :, :]
        aug_label = aug_label[aug_shuffle]

        aug_data = torch.from_numpy(aug_data).cuda()
        aug_data = aug_data.float()
        aug_label = torch.from_numpy(aug_label-1).cuda()
        aug_label = aug_label.long()
        return aug_data, aug_label

    def get_source_data(self):

        # train data
        self.total_data = scipy.io.loadmat(self.root + 'A0%dT_P.mat' % self.nSub)
        #self.total_data = scipy.io.loadmat(self.root + 'merged_Graz_2d_T.mat')

        self.train_data = self.total_data['data']
        self.train_label = self.total_data['label']

        # self.train_data = np.transpose(self.train_data, (2, 1, 0))
        self.train_data = np.expand_dims(self.train_data, axis=1)
        self.train_label = np.transpose(self.train_label)

        self.allData = self.train_data
        self.allLabel = self.train_label

        shuffle_num = np.random.permutation(len(self.allData))
        self.allData = self.allData[shuffle_num, :, :, :]
        self.allLabel = self.allLabel[shuffle_num]

        # test data
        self.test_tmp = scipy.io.loadmat(self.root + 'A0%dE_P.mat' % self.nSub)
        #self.test_tmp = scipy.io.loadmat(self.root + 'merged_Graz_2d_E.mat')
        self.test_data = self.test_tmp['data']
        self.test_label = self.test_tmp['label']

        # self.test_data = np.transpose(self.test_data, (2, 1, 0))
        self.test_data = np.expand_dims(self.test_data, axis=1)
        self.test_label = np.transpose(self.test_label)

        self.testData = self.test_data
        self.testLabel = np.squeeze(self.test_label)

        #print(self.allData)
        # standardize
        target_mean = np.mean(self.allData, axis=0)
        target_std = np.std(self.allData)

        self.allData = (self.allData - target_mean) / target_std
        self.testData = (self.testData - target_mean) / target_std

        # data shape: (trial, conv channel, electrode channel, time samples)
        return self.allData, self.allLabel, self.testData, self.testLabel


    def train(self):

        img, label, test_data, test_label = self.get_source_data()
        img = torch.from_numpy(img)
        label = torch.from_numpy(label - 1)

        dataset = torch.utils.data.TensorDataset(img, label)
        self.dataloader = torch.utils.data.DataLoader(dataset=dataset, batch_size=self.batch_size, shuffle=True)

        test_data = torch.from_numpy(test_data)
        test_label = torch.from_numpy(test_label - 1)
        test_dataset = torch.utils.data.TensorDataset(test_data, test_label)
        self.test_dataloader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=self.batch_size, shuffle=True)

        # Optimizers
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=self.lr, betas=(self.b1, self.b2))

        test_data = Variable(test_data.type(self.Tensor))
        test_label = Variable(test_label.type(self.LongTensor))

        bestAcc = 0
        averAcc = 0
        num = 0
        Y_true = 0
        Y_pred = 0

        # Train the cnn model
        total_step = len(self.dataloader)
        curr_lr = self.lr

        for e in range(self.n_epochs):
            # in_epoch = time.time()
            self.model.train()
            for i, (img, label) in enumerate(self.dataloader):

                img = Variable(img.cuda().type(self.Tensor))
                label = Variable(label.cuda().type(self.LongTensor))

                # data augmentation
                aug_data, aug_label = self.interaug(self.allData, self.allLabel)
                img = torch.cat((img, aug_data))

                label = torch.squeeze(label, dim=1)
                label = torch.cat((label, aug_label))


                tok, outputs = self.model(img)


                loss = self.criterion_cls(outputs, label)

                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()


            # out_epoch = time.time()


            # test process
            if (e + 1) % 1 == 0:
                self.model.eval()
                Tok, Cls = self.model(test_data)

                loss_test = self.criterion_cls(Cls, test_label)
                y_pred = torch.max(Cls, 1)[1]
                acc = float((y_pred == test_label).cpu().numpy().astype(int).sum()) / float(test_label.size(0))
                train_pred = torch.max(outputs, 1)[1]
                train_acc = float((train_pred == label).cpu().numpy().astype(int).sum()) / float(label.size(0))

                print('Epoch:', e,
                      '  Train loss: %.6f' % loss.detach().cpu().numpy(),
                      '  Test loss: %.6f' % loss_test.detach().cpu().numpy(),
                      '  Train accuracy %.6f' % train_acc,
                      '  Test accuracy is %.6f' % acc)

                self.log_write.write(str(e) + "    " +str(loss.detach().cpu().numpy())+"    "+
                                     str(loss_test.detach().cpu().numpy())+"    "+str(train_acc) +"     "+ str(acc)+ "\n")
                num = num + 1
                averAcc = averAcc + acc
                if acc > bestAcc:
                    bestAcc = acc
                    Y_true = test_label
                    Y_pred = y_pred


        torch.save(self.model.module.state_dict(), 'model.pth')
        averAcc = averAcc / num
        print('The average accuracy is:', averAcc)
        print('The best accuracy is:', bestAcc)
        self.log_write.write('The average accuracy is: ' + str(averAcc) + "\n")
        self.log_write.write('The best accuracy is: ' + str(bestAcc) + "\n")

        return bestAcc, averAcc, Y_true, Y_pred
        # writer.close()


def main():
    best = 0
    aver = 0
    result_write = open("sub_result.txt", "w")

    for i in range(50):
        starttime = datetime.datetime.now()


        seed_n = np.random.randint(2021)
        print('seed is ' + str(seed_n))
        random.seed(seed_n)
        np.random.seed(seed_n)
        torch.manual_seed(seed_n)
        torch.cuda.manual_seed(seed_n)
        torch.cuda.manual_seed_all(seed_n)


        print('Subject %d' % (i+1))
        exp = ExP(i + 1)

        bestAcc, averAcc, Y_true, Y_pred = exp.train()
        print('THE BEST ACCURACY IS ' + str(bestAcc))
        result_write.write('Subject ' + str(i + 1) + ' : ' + 'Seed is: ' + str(seed_n) + "\n")
        result_write.write('Subject ' + str(i + 1) + ' : ' + 'The best accuracy is: ' + str(bestAcc) + "\n")
        result_write.write('Subject ' + str(i + 1) + ' : ' + 'The average accuracy is: ' + str(averAcc) + "\n")

        endtime = datetime.datetime.now()
        print('subject %d duration: '%(i+1) + str(endtime - starttime))
        best = best + bestAcc
        aver = aver + averAcc
        if i == 0:
            yt = Y_true
            yp = Y_pred
        else:
            yt = torch.cat((yt, Y_true))
            yp = torch.cat((yp, Y_pred))


    best = best / 50
    aver = aver / 50

    result_write.write('**The average Best accuracy is: ' + str(best) + "\n")
    result_write.write('The average Aver accuracy is: ' + str(aver) + "\n")
    result_write.close()


if __name__ == "__main__":
    print(time.asctime(time.localtime(time.time())))
    main()
    print(time.asctime(time.localtime(time.time())))
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch: 147   Train loss: 0.163928   Test loss: 1.852423   Train accuracy 0.953488   Test accuracy is 0.720000
# Epoch: 148   Train loss: 0.059475   Test loss: 1.565439   Train accuracy 0.976744   Test accuracy is 0.760000
# Epoch: 149   Train loss: 0.024905   Test loss: 1.326545   Train accuracy 1.000000   Test accuracy is 0.780000
# The average accuracy is: 0.6397333333333329
# The best accuracy is: 0.82
# THE BEST ACCURACY IS 0.82
# subject 18 duration: 0:00:38.804994
# seed is 144
# Subject 19
# Epoch: 0   Train loss: 1.424325   Test loss: 1.380856   Train accuracy 0.255814   Test accuracy is 0.260000
# Epoch: 1   Train loss: 1.427411   Test loss: 1.378578   Train accuracy 0.139535   Test accuracy is 0.260000
# Epoch: 2   Train loss: 1.403521   Test loss: 1.378426   Train accuracy 0.232558   Test accuracy is 0.260000
# Epoch: 3   Train loss: 1.425018   Test loss: 1.378954   Train accuracy 0.162791   Test accuracy is 0.260000
# Epoch: 4   Train loss: 1.425983   Test loss: 1.371406   Train accuracy 0.186047   Test accuracy is 0.260000
# Epoch: 5   Train loss: 1.398466   Test loss: 1.362889   Train accuracy 0.232558   Test accuracy is 0.280000
# Epoch: 6   Train loss: 1.401188   Test loss: 1.350564   Train accuracy 0.279070   Test accuracy is 0.340000
# Epoch: 7   Train loss: 1.299839   Test loss: 1.314094   Train accuracy 0.372093   Test accuracy is 0.340000
# Epoch: 8   Train loss: 1.307034   Test loss: 1.286355   Train accuracy 0.465116   Test accuracy is 0.400000
# Epoch: 9   Train loss: 1.264802   Test loss: 1.272197   Train accuracy 0.348837   Test accuracy is 0.400000
# Epoch: 10   Train loss: 1.211735   Test loss: 1.300173   Train accuracy 0.465116   Test accuracy is 0.400000
# Epoch: 11   Train loss: 1.160589   Test loss: 1.313658   Train accuracy 0.465116   Test accuracy is 0.400000
# Epoch: 12   Train loss: 1.145015   Test loss: 1.363390   Train accuracy 0.488372   Test accuracy is 0.420000
# Epoch: 13   Train loss: 1.068644   Test loss: 1.296429   Train accuracy 0.395349   Test accuracy is 0.400000
# Epoch: 14   Train loss: 1.081995   Test loss: 1.393441   Train accuracy 0.465116   Test accuracy is 0.300000
# Epoch: 15   Train loss: 0.931206   Test loss: 1.340791   Train accuracy 0.488372   Test accuracy is 0.280000
# Epoch: 16   Train loss: 1.048326   Test loss: 1.243741   Train accuracy 0.418605   Test accuracy is 0.360000
# Epoch: 17   Train loss: 0.906040   Test loss: 1.192875   Train accuracy 0.511628   Test accuracy is 0.420000
# Epoch: 18   Train loss: 0.918680   Test loss: 1.446004   Train accuracy 0.627907   Test accuracy is 0.300000
# Epoch: 19   Train loss: 0.964419   Test loss: 1.256051   Train accuracy 0.465116   Test accuracy is 0.440000
# Epoch: 20   Train loss: 0.965975   Test loss: 1.268430   Train accuracy 0.534884   Test accuracy is 0.340000
# Epoch: 21   Train loss: 0.901825   Test loss: 1.249970   Train accuracy 0.488372   Test accuracy is 0.460000
# Epoch: 22   Train loss: 1.115555   Test loss: 1.523042   Train accuracy 0.418605   Test accuracy is 0.300000
# Epoch: 23   Train loss: 0.904161   Test loss: 1.326725   Train accuracy 0.558140   Test accuracy is 0.360000
# Epoch: 24   Train loss: 0.980977   Test loss: 1.310943   Train accuracy 0.441860   Test accuracy is 0.320000
# Epoch: 25   Train loss: 0.937264   Test loss: 1.114899   Train accuracy 0.441860   Test accuracy is 0.380000
# Epoch: 26   Train loss: 0.902291   Test loss: 1.180841   Train accuracy 0.558140   Test accuracy is 0.480000
# Epoch: 27   Train loss: 0.872221   Test loss: 1.278715   Train accuracy 0.511628   Test accuracy is 0.500000
# Epoch: 28   Train loss: 1.059821   Test loss: 1.179849   Train accuracy 0.372093   Test accuracy is 0.480000
# Epoch: 29   Train loss: 0.980269   Test loss: 1.256791   Train accuracy 0.488372   Test accuracy is 0.500000
# Epoch: 30   Train loss: 0.926753   Test loss: 1.465559   Train accuracy 0.441860   Test accuracy is 0.320000
# Epoch: 31   Train loss: 0.845670   Test loss: 1.281751   Train accuracy 0.534884   Test accuracy is 0.500000
# Epoch: 32   Train loss: 0.891860   Test loss: 1.268955   Train accuracy 0.465116   Test accuracy is 0.520000
# Epoch: 33   Train loss: 1.021866   Test loss: 1.125161   Train accuracy 0.418605   Test accuracy is 0.460000
# Epoch: 34   Train loss: 0.864772   Test loss: 1.285565   Train accuracy 0.488372   Test accuracy is 0.460000
# Epoch: 35   Train loss: 0.894351   Test loss: 1.213173   Train accuracy 0.511628   Test accuracy is 0.500000
# Epoch: 36   Train loss: 0.855953   Test loss: 1.215582   Train accuracy 0.558140   Test accuracy is 0.500000
# Epoch: 37   Train loss: 0.880914   Test loss: 1.233870   Train accuracy 0.558140   Test accuracy is 0.500000
# Epoch: 38   Train loss: 0.851654   Test loss: 1.422307   Train accuracy 0.511628   Test accuracy is 0.340000
# Epoch: 39   Train loss: 0.834129   Test loss: 1.159776   Train accuracy 0.534884   Test accuracy is 0.460000
# Epoch: 40   Train loss: 0.823507   Test loss: 1.256406   Train accuracy 0.558140   Test accuracy is 0.500000
# Epoch: 41   Train loss: 0.867874   Test loss: 1.205056   Train accuracy 0.558140   Test accuracy is 0.500000
# Epoch: 42   Train loss: 0.858375   Test loss: 1.290245   Train accuracy 0.534884   Test accuracy is 0.420000
# Epoch: 43   Train loss: 0.858584   Test loss: 1.402727   Train accuracy 0.674419   Test accuracy is 0.340000
# Epoch: 44   Train loss: 0.813274   Test loss: 1.331902   Train accuracy 0.604651   Test accuracy is 0.480000
# Epoch: 45   Train loss: 0.878872   Test loss: 1.378312   Train accuracy 0.558140   Test accuracy is 0.480000
# Epoch: 46   Train loss: 0.983048   Test loss: 1.445870   Train accuracy 0.558140   Test accuracy is 0.480000
# Epoch: 47   Train loss: 0.794828   Test loss: 1.243274   Train accuracy 0.674419   Test accuracy is 0.500000
# Epoch: 48   Train loss: 0.773176   Test loss: 1.267709   Train accuracy 0.627907   Test accuracy is 0.500000
# Epoch: 49   Train loss: 0.739717   Test loss: 1.416559   Train accuracy 0.674419   Test accuracy is 0.420000
# Epoch: 50   Train loss: 0.674141   Test loss: 1.241024   Train accuracy 0.720930   Test accuracy is 0.540000
# Epoch: 51   Train loss: 0.692879   Test loss: 1.404933   Train accuracy 0.651163   Test accuracy is 0.500000
# Epoch: 52   Train loss: 0.886716   Test loss: 1.385463   Train accuracy 0.604651   Test accuracy is 0.480000
# Epoch: 53   Train loss: 0.611533   Test loss: 1.358733   Train accuracy 0.744186   Test accuracy is 0.460000
# Epoch: 54   Train loss: 0.854650   Test loss: 1.668300   Train accuracy 0.651163   Test accuracy is 0.440000
# Epoch: 55   Train loss: 0.714217   Test loss: 1.290276   Train accuracy 0.697674   Test accuracy is 0.500000
# Epoch: 56   Train loss: 0.644059   Test loss: 1.446896   Train accuracy 0.767442   Test accuracy is 0.460000
# Epoch: 57   Train loss: 0.762377   Test loss: 1.695806   Train accuracy 0.604651   Test accuracy is 0.380000
# Epoch: 58   Train loss: 0.682089   Test loss: 1.804069   Train accuracy 0.744186   Test accuracy is 0.380000
# Epoch: 59   Train loss: 0.553088   Test loss: 1.438843   Train accuracy 0.790698   Test accuracy is 0.520000
# Epoch: 60   Train loss: 0.647022   Test loss: 1.727757   Train accuracy 0.697674   Test accuracy is 0.480000
# Epoch: 61   Train loss: 0.635673   Test loss: 1.589476   Train accuracy 0.720930   Test accuracy is 0.500000
# Epoch: 62   Train loss: 0.608180   Test loss: 1.727848   Train accuracy 0.720930   Test accuracy is 0.460000
# Epoch: 63   Train loss: 0.574874   Test loss: 1.682173   Train accuracy 0.744186   Test accuracy is 0.520000
# Epoch: 64   Train loss: 0.705256   Test loss: 1.724015   Train accuracy 0.720930   Test accuracy is 0.420000
# Epoch: 65   Train loss: 0.751452   Test loss: 2.158116   Train accuracy 0.651163   Test accuracy is 0.440000
# Epoch: 66   Train loss: 0.535824   Test loss: 1.739178   Train accuracy 0.790698   Test accuracy is 0.500000
# Epoch: 67   Train loss: 0.576486   Test loss: 2.046476   Train accuracy 0.883721   Test accuracy is 0.420000
# Epoch: 68   Train loss: 0.494930   Test loss: 1.846532   Train accuracy 0.767442   Test accuracy is 0.500000
# Epoch: 69   Train loss: 0.479982   Test loss: 2.044522   Train accuracy 0.720930   Test accuracy is 0.380000
# Epoch: 70   Train loss: 0.689326   Test loss: 2.120236   Train accuracy 0.674419   Test accuracy is 0.420000
# Epoch: 71   Train loss: 0.512145   Test loss: 1.991823   Train accuracy 0.720930   Test accuracy is 0.460000
# Epoch: 72   Train loss: 0.485091   Test loss: 3.444008   Train accuracy 0.813953   Test accuracy is 0.300000
# Epoch: 73   Train loss: 0.479443   Test loss: 2.027645   Train accuracy 0.860465   Test accuracy is 0.460000
# Epoch: 74   Train loss: 0.434516   Test loss: 2.452656   Train accuracy 0.860465   Test accuracy is 0.380000
# Epoch: 75   Train loss: 0.540954   Test loss: 1.846330   Train accuracy 0.790698   Test accuracy is 0.500000
# Epoch: 76   Train loss: 0.592400   Test loss: 2.690566   Train accuracy 0.767442   Test accuracy is 0.460000
# Epoch: 77   Train loss: 0.407596   Test loss: 1.865019   Train accuracy 0.883721   Test accuracy is 0.480000
# Epoch: 78   Train loss: 0.516499   Test loss: 1.916507   Train accuracy 0.813953   Test accuracy is 0.520000
# Epoch: 79   Train loss: 0.384732   Test loss: 3.757259   Train accuracy 0.883721   Test accuracy is 0.320000
# Epoch: 80   Train loss: 0.474666   Test loss: 2.026830   Train accuracy 0.790698   Test accuracy is 0.460000
# Epoch: 81   Train loss: 0.370885   Test loss: 3.262595   Train accuracy 0.860465   Test accuracy is 0.360000
# Epoch: 82   Train loss: 0.388538   Test loss: 2.041543   Train accuracy 0.883721   Test accuracy is 0.480000
# Epoch: 83   Train loss: 0.392505   Test loss: 2.002681   Train accuracy 0.813953   Test accuracy is 0.460000
# Epoch: 84   Train loss: 0.382931   Test loss: 3.412192   Train accuracy 0.883721   Test accuracy is 0.400000
# Epoch: 85   Train loss: 0.389906   Test loss: 2.527132   Train accuracy 0.837209   Test accuracy is 0.420000
# Epoch: 86   Train loss: 0.509387   Test loss: 2.355608   Train accuracy 0.744186   Test accuracy is 0.440000
# Epoch: 87   Train loss: 0.547265   Test loss: 2.674267   Train accuracy 0.837209   Test accuracy is 0.420000
# Epoch: 88   Train loss: 0.522817   Test loss: 2.366481   Train accuracy 0.837209   Test accuracy is 0.500000
# Epoch: 89   Train loss: 0.373727   Test loss: 3.164377   Train accuracy 0.790698   Test accuracy is 0.400000
# Epoch: 90   Train loss: 0.411796   Test loss: 2.614512   Train accuracy 0.813953   Test accuracy is 0.460000
# Epoch: 91   Train loss: 0.421274   Test loss: 2.339009   Train accuracy 0.860465   Test accuracy is 0.480000
# Epoch: 92   Train loss: 0.405211   Test loss: 2.167922   Train accuracy 0.837209   Test accuracy is 0.460000
# Epoch: 93   Train loss: 0.390149   Test loss: 2.364297   Train accuracy 0.813953   Test accuracy is 0.460000
# Epoch: 94   Train loss: 0.364428   Test loss: 4.455043   Train accuracy 0.837209   Test accuracy is 0.320000
# Epoch: 95   Train loss: 0.441782   Test loss: 2.116086   Train accuracy 0.837209   Test accuracy is 0.400000
# Epoch: 96   Train loss: 0.514896   Test loss: 3.163427   Train accuracy 0.813953   Test accuracy is 0.400000
# Epoch: 97   Train loss: 0.374743   Test loss: 2.732158   Train accuracy 0.837209   Test accuracy is 0.420000
# Epoch: 98   Train loss: 0.209296   Test loss: 2.880333   Train accuracy 0.930233   Test accuracy is 0.480000
# Epoch: 99   Train loss: 0.225877   Test loss: 3.019034   Train accuracy 0.906977   Test accuracy is 0.400000
# Epoch: 100   Train loss: 0.229913   Test loss: 2.009787   Train accuracy 0.930233   Test accuracy is 0.480000
# Epoch: 101   Train loss: 0.360110   Test loss: 2.119915   Train accuracy 0.906977   Test accuracy is 0.500000
# Epoch: 102   Train loss: 0.270231   Test loss: 3.273813   Train accuracy 0.883721   Test accuracy is 0.440000
# Epoch: 103   Train loss: 0.283005   Test loss: 2.204650   Train accuracy 0.883721   Test accuracy is 0.500000
# Epoch: 104   Train loss: 0.411642   Test loss: 2.758443   Train accuracy 0.837209   Test accuracy is 0.380000
# Epoch: 105   Train loss: 0.336940   Test loss: 2.770806   Train accuracy 0.860465   Test accuracy is 0.440000
# Epoch: 106   Train loss: 0.375684   Test loss: 2.431374   Train accuracy 0.837209   Test accuracy is 0.420000
# Epoch: 107   Train loss: 0.309065   Test loss: 2.300291   Train accuracy 0.837209   Test accuracy is 0.500000
# Epoch: 108   Train loss: 0.402886   Test loss: 4.490791   Train accuracy 0.813953   Test accuracy is 0.400000
# Epoch: 109   Train loss: 0.295908   Test loss: 3.145668   Train accuracy 0.906977   Test accuracy is 0.460000
# Epoch: 110   Train loss: 0.382010   Test loss: 3.332913   Train accuracy 0.860465   Test accuracy is 0.380000
# Epoch: 111   Train loss: 0.382815   Test loss: 3.166621   Train accuracy 0.906977   Test accuracy is 0.460000
# Epoch: 112   Train loss: 0.159693   Test loss: 2.546093   Train accuracy 0.930233   Test accuracy is 0.440000
# Epoch: 113   Train loss: 0.137742   Test loss: 2.307036   Train accuracy 0.953488   Test accuracy is 0.540000
# Epoch: 114   Train loss: 0.490901   Test loss: 3.382931   Train accuracy 0.883721   Test accuracy is 0.420000
# Epoch: 115   Train loss: 0.257255   Test loss: 2.784550   Train accuracy 0.860465   Test accuracy is 0.460000
# Epoch: 116   Train loss: 0.276314   Test loss: 2.475061   Train accuracy 0.860465   Test accuracy is 0.440000
# Epoch: 117   Train loss: 0.456343   Test loss: 3.947082   Train accuracy 0.837209   Test accuracy is 0.380000
# Epoch: 118   Train loss: 0.283882   Test loss: 3.664402   Train accuracy 0.906977   Test accuracy is 0.440000
# Epoch: 119   Train loss: 0.208936   Test loss: 2.282906   Train accuracy 0.930233   Test accuracy is 0.460000
# Epoch: 120   Train loss: 0.186940   Test loss: 3.920753   Train accuracy 0.906977   Test accuracy is 0.460000
# Epoch: 121   Train loss: 0.222132   Test loss: 2.637045   Train accuracy 0.930233   Test accuracy is 0.460000
# Epoch: 122   Train loss: 0.222987   Test loss: 2.080517   Train accuracy 0.930233   Test accuracy is 0.540000
# Epoch: 123   Train loss: 0.138217   Test loss: 2.542440   Train accuracy 0.906977   Test accuracy is 0.480000
# Epoch: 124   Train loss: 0.203598   Test loss: 3.021592   Train accuracy 0.906977   Test accuracy is 0.460000
# Epoch: 125   Train loss: 0.267718   Test loss: 2.150910   Train accuracy 0.860465   Test accuracy is 0.460000
# Epoch: 126   Train loss: 0.323662   Test loss: 4.037521   Train accuracy 0.837209   Test accuracy is 0.380000
# Epoch: 127   Train loss: 0.389242   Test loss: 2.168377   Train accuracy 0.837209   Test accuracy is 0.480000
# Epoch: 128   Train loss: 0.524582   Test loss: 4.140541   Train accuracy 0.837209   Test accuracy is 0.380000
# Epoch: 129   Train loss: 0.247002   Test loss: 3.280175   Train accuracy 0.930233   Test accuracy is 0.440000
# Epoch: 130   Train loss: 0.199116   Test loss: 2.879400   Train accuracy 0.953488   Test accuracy is 0.480000
# Epoch: 131   Train loss: 0.240580   Test loss: 2.230521   Train accuracy 0.906977   Test accuracy is 0.540000
# Epoch: 132   Train loss: 0.062929   Test loss: 2.384474   Train accuracy 0.976744   Test accuracy is 0.500000
# Epoch: 133   Train loss: 0.270551   Test loss: 2.457735   Train accuracy 0.953488   Test accuracy is 0.460000
# Epoch: 134   Train loss: 0.181636   Test loss: 2.273568   Train accuracy 0.930233   Test accuracy is 0.520000
# Epoch: 135   Train loss: 0.113206   Test loss: 2.754406   Train accuracy 0.953488   Test accuracy is 0.480000
# Epoch: 136   Train loss: 0.129288   Test loss: 4.056064   Train accuracy 0.953488   Test accuracy is 0.440000
# Epoch: 137   Train loss: 0.125294   Test loss: 2.602438   Train accuracy 0.953488   Test accuracy is 0.560000
# Epoch: 138   Train loss: 0.192236   Test loss: 2.739816   Train accuracy 0.906977   Test accuracy is 0.440000
# Epoch: 139   Train loss: 0.376318   Test loss: 2.758619   Train accuracy 0.906977   Test accuracy is 0.520000
# Epoch: 140   Train loss: 0.096427   Test loss: 2.381334   Train accuracy 0.976744   Test accuracy is 0.460000
# Epoch: 141   Train loss: 0.136746   Test loss: 2.434772   Train accuracy 0.953488   Test accuracy is 0.480000
# Epoch: 142   Train loss: 0.282020   Test loss: 3.287024   Train accuracy 0.883721   Test accuracy is 0.480000
# Epoch: 143   Train loss: 0.200464   Test loss: 2.603748   Train accuracy 0.930233   Test accuracy is 0.460000
# Epoch: 144   Train loss: 0.330042   Test loss: 3.373880   Train accuracy 0.883721   Test accuracy is 0.480000
# Epoch: 145   Train loss: 0.356006   Test loss: 3.058192   Train accuracy 0.813953   Test accuracy is 0.460000
# Epoch: 146   Train loss: 0.518250   Test loss: 2.945800   Train accuracy 0.837209   Test accuracy is 0.440000
# Epoch: 147   Train loss: 0.203706   Test loss: 3.001262   Train accuracy 0.883721   Test accuracy is 0.380000
# Epoch: 148   Train loss: 0.249428   Test loss: 2.712183   Train accuracy 0.930233   Test accuracy is 0.420000
# Epoch: 149   Train loss: 0.198893   Test loss: 2.270003   Train accuracy 0.906977   Test accuracy is 0.480000
# The average accuracy is: 0.4349333333333333
# The best accuracy is: 0.56
# THE BEST ACCURACY IS 0.56
# subject 19 duration: 0:00:38.010286
# seed is 1117
# Subject 20
# Epoch: 0   Train loss: 1.415037   Test loss: 1.398314   Train accuracy 0.232558   Test accuracy is 0.200000
# Epoch: 1   Train loss: 1.451747   Test loss: 1.405558   Train accuracy 0.186047   Test accuracy is 0.200000
# Epoch: 2   Train loss: 1.408499   Test loss: 1.415999   Train accuracy 0.255814   Test accuracy is 0.200000
# Epoch: 3   Train loss: 1.379712   Test loss: 1.414662   Train accuracy 0.302326   Test accuracy is 0.200000
# Epoch: 4   Train loss: 1.421030   Test loss: 1.416341   Train accuracy 0.232558   Test accuracy is 0.200000
# Epoch: 5   Train loss: 1.380277   Test loss: 1.417043   Train accuracy 0.348837   Test accuracy is 0.200000
# Epoch: 6   Train loss: 1.406128   Test loss: 1.417541   Train accuracy 0.232558   Test accuracy is 0.200000
# Epoch: 7   Train loss: 1.398284   Test loss: 1.429443   Train accuracy 0.255814   Test accuracy is 0.200000
# Epoch: 8   Train loss: 1.396522   Test loss: 1.433276   Train accuracy 0.302326   Test accuracy is 0.200000
# Epoch: 9   Train loss: 1.341856   Test loss: 1.445303   Train accuracy 0.302326   Test accuracy is 0.200000
# Epoch: 10   Train loss: 1.379012   Test loss: 1.448115   Train accuracy 0.325581   Test accuracy is 0.200000
# Epoch: 11   Train loss: 1.395982   Test loss: 1.458176   Train accuracy 0.279070   Test accuracy is 0.200000
# Epoch: 12   Train loss: 1.408579   Test loss: 1.461669   Train accuracy 0.255814   Test accuracy is 0.200000
# Epoch: 13   Train loss: 1.393700   Test loss: 1.466568   Train accuracy 0.232558   Test accuracy is 0.200000
# Epoch: 14   Train loss: 1.421193   Test loss: 1.457643   Train accuracy 0.302326   Test accuracy is 0.200000
# Epoch: 15   Train loss: 1.381518   Test loss: 1.460348   Train accuracy 0.209302   Test accuracy is 0.220000
# Epoch: 16   Train loss: 1.339419   Test loss: 1.485792   Train accuracy 0.325581   Test accuracy is 0.200000
# Epoch: 17   Train loss: 1.326410   Test loss: 1.494871   Train accuracy 0.372093   Test accuracy is 0.220000
# Epoch: 18   Train loss: 1.385348   Test loss: 1.540465   Train accuracy 0.279070   Test accuracy is 0.200000
# Epoch: 19   Train loss: 1.333427   Test loss: 1.563474   Train accuracy 0.372093   Test accuracy is 0.200000
# Epoch: 20   Train loss: 1.332886   Test loss: 1.630627   Train accuracy 0.279070   Test accuracy is 0.260000
# Epoch: 21   Train loss: 1.241029   Test loss: 1.690262   Train accuracy 0.418605   Test accuracy is 0.200000
# Epoch: 22   Train loss: 1.226356   Test loss: 1.731575   Train accuracy 0.511628   Test accuracy is 0.200000
# Epoch: 23   Train loss: 1.458659   Test loss: 1.735875   Train accuracy 0.302326   Test accuracy is 0.220000
# Epoch: 24   Train loss: 1.281868   Test loss: 1.701804   Train accuracy 0.372093   Test accuracy is 0.240000
# Epoch: 25   Train loss: 1.294381   Test loss: 1.938776   Train accuracy 0.488372   Test accuracy is 0.260000
# Epoch: 26   Train loss: 1.276938   Test loss: 2.039954   Train accuracy 0.348837   Test accuracy is 0.260000
# Epoch: 27   Train loss: 1.352042   Test loss: 2.135135   Train accuracy 0.255814   Test accuracy is 0.260000
# Epoch: 28   Train loss: 1.273681   Test loss: 2.165661   Train accuracy 0.348837   Test accuracy is 0.260000
# Epoch: 29   Train loss: 1.181169   Test loss: 2.221676   Train accuracy 0.441860   Test accuracy is 0.200000
# Epoch: 30   Train loss: 1.182745   Test loss: 2.287993   Train accuracy 0.395349   Test accuracy is 0.220000
# Epoch: 31   Train loss: 1.339449   Test loss: 2.318022   Train accuracy 0.325581   Test accuracy is 0.260000
# Epoch: 32   Train loss: 1.132766   Test loss: 2.348674   Train accuracy 0.418605   Test accuracy is 0.260000
# Epoch: 33   Train loss: 1.143300   Test loss: 2.561344   Train accuracy 0.511628   Test accuracy is 0.200000
# Epoch: 34   Train loss: 1.035634   Test loss: 2.327386   Train accuracy 0.534884   Test accuracy is 0.240000
# Epoch: 35   Train loss: 1.334079   Test loss: 2.426960   Train accuracy 0.418605   Test accuracy is 0.200000
# Epoch: 36   Train loss: 1.057616   Test loss: 2.174211   Train accuracy 0.488372   Test accuracy is 0.260000
# Epoch: 37   Train loss: 1.096232   Test loss: 2.656013   Train accuracy 0.534884   Test accuracy is 0.200000
# Epoch: 38   Train loss: 1.115886   Test loss: 1.930845   Train accuracy 0.511628   Test accuracy is 0.280000
# Epoch: 39   Train loss: 1.123505   Test loss: 2.776881   Train accuracy 0.418605   Test accuracy is 0.220000
# Epoch: 40   Train loss: 1.094641   Test loss: 2.538941   Train accuracy 0.441860   Test accuracy is 0.200000
# Epoch: 41   Train loss: 1.090334   Test loss: 2.595549   Train accuracy 0.465116   Test accuracy is 0.200000
# Epoch: 42   Train loss: 1.100936   Test loss: 2.813958   Train accuracy 0.348837   Test accuracy is 0.200000
# Epoch: 43   Train loss: 1.139756   Test loss: 2.894364   Train accuracy 0.395349   Test accuracy is 0.240000
# Epoch: 44   Train loss: 1.126877   Test loss: 2.872691   Train accuracy 0.441860   Test accuracy is 0.260000
# Epoch: 45   Train loss: 1.006383   Test loss: 2.696154   Train accuracy 0.465116   Test accuracy is 0.280000
# Epoch: 46   Train loss: 0.890387   Test loss: 3.040048   Train accuracy 0.627907   Test accuracy is 0.280000
# Epoch: 47   Train loss: 1.103909   Test loss: 2.767883   Train accuracy 0.558140   Test accuracy is 0.300000
# Epoch: 48   Train loss: 1.058406   Test loss: 2.390326   Train accuracy 0.441860   Test accuracy is 0.340000
# Epoch: 49   Train loss: 1.032141   Test loss: 2.268066   Train accuracy 0.511628   Test accuracy is 0.340000
# Epoch: 50   Train loss: 1.122385   Test loss: 2.669659   Train accuracy 0.465116   Test accuracy is 0.300000
# Epoch: 51   Train loss: 1.165971   Test loss: 3.060612   Train accuracy 0.302326   Test accuracy is 0.260000
# Epoch: 52   Train loss: 0.984875   Test loss: 3.019410   Train accuracy 0.534884   Test accuracy is 0.260000
# Epoch: 53   Train loss: 0.964284   Test loss: 2.199586   Train accuracy 0.604651   Test accuracy is 0.380000
# Epoch: 54   Train loss: 1.013095   Test loss: 2.809932   Train accuracy 0.534884   Test accuracy is 0.360000
# Epoch: 55   Train loss: 0.925787   Test loss: 3.513983   Train accuracy 0.558140   Test accuracy is 0.260000
# Epoch: 56   Train loss: 0.961533   Test loss: 1.828464   Train accuracy 0.558140   Test accuracy is 0.420000
# Epoch: 57   Train loss: 0.941793   Test loss: 2.371032   Train accuracy 0.651163   Test accuracy is 0.400000
# Epoch: 58   Train loss: 0.908889   Test loss: 2.668575   Train accuracy 0.581395   Test accuracy is 0.280000
# Epoch: 59   Train loss: 1.015245   Test loss: 2.996179   Train accuracy 0.534884   Test accuracy is 0.260000
# Epoch: 60   Train loss: 0.956418   Test loss: 3.245136   Train accuracy 0.511628   Test accuracy is 0.260000
# Epoch: 61   Train loss: 0.925143   Test loss: 2.275570   Train accuracy 0.534884   Test accuracy is 0.360000
# Epoch: 62   Train loss: 0.924972   Test loss: 2.565224   Train accuracy 0.488372   Test accuracy is 0.320000
# Epoch: 63   Train loss: 0.870112   Test loss: 3.102278   Train accuracy 0.488372   Test accuracy is 0.260000
# Epoch: 64   Train loss: 1.045769   Test loss: 2.478349   Train accuracy 0.534884   Test accuracy is 0.420000
# Epoch: 65   Train loss: 0.979793   Test loss: 2.562166   Train accuracy 0.465116   Test accuracy is 0.360000
# Epoch: 66   Train loss: 0.899418   Test loss: 2.295704   Train accuracy 0.558140   Test accuracy is 0.360000
# Epoch: 67   Train loss: 0.957195   Test loss: 2.724670   Train accuracy 0.511628   Test accuracy is 0.300000
# Epoch: 68   Train loss: 0.881470   Test loss: 2.565202   Train accuracy 0.511628   Test accuracy is 0.360000
# Epoch: 69   Train loss: 0.756930   Test loss: 2.264311   Train accuracy 0.697674   Test accuracy is 0.460000
# Epoch: 70   Train loss: 0.976917   Test loss: 2.864808   Train accuracy 0.441860   Test accuracy is 0.300000
# Epoch: 71   Train loss: 0.853572   Test loss: 2.930310   Train accuracy 0.651163   Test accuracy is 0.320000
# Epoch: 72   Train loss: 0.943763   Test loss: 3.408855   Train accuracy 0.465116   Test accuracy is 0.260000
# Epoch: 73   Train loss: 0.987619   Test loss: 2.054480   Train accuracy 0.604651   Test accuracy is 0.340000
# Epoch: 74   Train loss: 1.074629   Test loss: 1.761378   Train accuracy 0.465116   Test accuracy is 0.440000
# Epoch: 75   Train loss: 0.859642   Test loss: 1.725951   Train accuracy 0.604651   Test accuracy is 0.440000
# Epoch: 76   Train loss: 0.962130   Test loss: 2.878479   Train accuracy 0.511628   Test accuracy is 0.300000
# Epoch: 77   Train loss: 0.815145   Test loss: 3.616844   Train accuracy 0.627907   Test accuracy is 0.260000
# Epoch: 78   Train loss: 1.070863   Test loss: 2.497714   Train accuracy 0.534884   Test accuracy is 0.400000
# Epoch: 79   Train loss: 0.872034   Test loss: 2.116928   Train accuracy 0.511628   Test accuracy is 0.440000
# Epoch: 80   Train loss: 0.797412   Test loss: 1.717027   Train accuracy 0.627907   Test accuracy is 0.480000
# Epoch: 81   Train loss: 0.757145   Test loss: 3.391360   Train accuracy 0.627907   Test accuracy is 0.280000
# Epoch: 82   Train loss: 0.804610   Test loss: 2.323259   Train accuracy 0.697674   Test accuracy is 0.400000
# Epoch: 83   Train loss: 0.746286   Test loss: 2.419754   Train accuracy 0.604651   Test accuracy is 0.360000
# Epoch: 84   Train loss: 1.124745   Test loss: 3.683394   Train accuracy 0.465116   Test accuracy is 0.260000
# Epoch: 85   Train loss: 0.829985   Test loss: 2.908298   Train accuracy 0.697674   Test accuracy is 0.380000
# Epoch: 86   Train loss: 0.956172   Test loss: 1.848276   Train accuracy 0.511628   Test accuracy is 0.400000
# Epoch: 87   Train loss: 0.931440   Test loss: 2.503021   Train accuracy 0.627907   Test accuracy is 0.300000
# Epoch: 88   Train loss: 0.730121   Test loss: 2.414029   Train accuracy 0.674419   Test accuracy is 0.340000
# Epoch: 89   Train loss: 0.765598   Test loss: 2.167917   Train accuracy 0.511628   Test accuracy is 0.320000
# Epoch: 90   Train loss: 0.814166   Test loss: 2.038538   Train accuracy 0.651163   Test accuracy is 0.400000
# Epoch: 91   Train loss: 1.062595   Test loss: 3.877943   Train accuracy 0.395349   Test accuracy is 0.260000
# Epoch: 92   Train loss: 0.833654   Test loss: 3.772760   Train accuracy 0.581395   Test accuracy is 0.280000
# Epoch: 93   Train loss: 0.746781   Test loss: 2.803653   Train accuracy 0.697674   Test accuracy is 0.340000
# Epoch: 94   Train loss: 0.886794   Test loss: 3.445763   Train accuracy 0.581395   Test accuracy is 0.320000
# Epoch: 95   Train loss: 0.828588   Test loss: 2.431785   Train accuracy 0.627907   Test accuracy is 0.380000
# Epoch: 96   Train loss: 0.609884   Test loss: 2.144790   Train accuracy 0.697674   Test accuracy is 0.360000
# Epoch: 97   Train loss: 0.735578   Test loss: 2.560092   Train accuracy 0.627907   Test accuracy is 0.320000
# Epoch: 98   Train loss: 0.708677   Test loss: 3.195367   Train accuracy 0.767442   Test accuracy is 0.320000
# Epoch: 99   Train loss: 0.710799   Test loss: 4.157209   Train accuracy 0.720930   Test accuracy is 0.260000
# Epoch: 100   Train loss: 0.654972   Test loss: 3.180946   Train accuracy 0.767442   Test accuracy is 0.360000
# Epoch: 101   Train loss: 0.711334   Test loss: 2.753110   Train accuracy 0.697674   Test accuracy is 0.380000
# Epoch: 102   Train loss: 0.514071   Test loss: 2.273642   Train accuracy 0.790698   Test accuracy is 0.400000
# Epoch: 103   Train loss: 0.718996   Test loss: 2.574088   Train accuracy 0.651163   Test accuracy is 0.380000
# Epoch: 104   Train loss: 0.727650   Test loss: 3.648480   Train accuracy 0.674419   Test accuracy is 0.340000
# Epoch: 105   Train loss: 0.663788   Test loss: 2.519316   Train accuracy 0.674419   Test accuracy is 0.400000
# Epoch: 106   Train loss: 0.671500   Test loss: 2.037154   Train accuracy 0.720930   Test accuracy is 0.460000
# Epoch: 107   Train loss: 0.566052   Test loss: 2.048446   Train accuracy 0.767442   Test accuracy is 0.440000
# Epoch: 108   Train loss: 0.710579   Test loss: 2.268823   Train accuracy 0.697674   Test accuracy is 0.380000
# Epoch: 109   Train loss: 0.918655   Test loss: 3.853601   Train accuracy 0.604651   Test accuracy is 0.300000
# Epoch: 110   Train loss: 0.742146   Test loss: 4.158599   Train accuracy 0.558140   Test accuracy is 0.280000
# Epoch: 111   Train loss: 0.624970   Test loss: 4.557663   Train accuracy 0.697674   Test accuracy is 0.260000
# Epoch: 112   Train loss: 0.703030   Test loss: 2.930728   Train accuracy 0.720930   Test accuracy is 0.420000
# Epoch: 113   Train loss: 0.734305   Test loss: 4.003017   Train accuracy 0.720930   Test accuracy is 0.340000
# Epoch: 114   Train loss: 0.780598   Test loss: 2.891608   Train accuracy 0.604651   Test accuracy is 0.400000
# Epoch: 115   Train loss: 0.673872   Test loss: 2.729030   Train accuracy 0.627907   Test accuracy is 0.440000
# Epoch: 116   Train loss: 0.649138   Test loss: 2.390695   Train accuracy 0.604651   Test accuracy is 0.480000
# Epoch: 117   Train loss: 0.643625   Test loss: 2.125230   Train accuracy 0.720930   Test accuracy is 0.420000
# Epoch: 118   Train loss: 0.661965   Test loss: 2.299986   Train accuracy 0.674419   Test accuracy is 0.400000
# Epoch: 119   Train loss: 0.840572   Test loss: 2.221651   Train accuracy 0.604651   Test accuracy is 0.440000
# Epoch: 120   Train loss: 0.570251   Test loss: 2.412981   Train accuracy 0.744186   Test accuracy is 0.460000
# Epoch: 121   Train loss: 0.524959   Test loss: 4.416115   Train accuracy 0.790698   Test accuracy is 0.280000
# Epoch: 122   Train loss: 0.550038   Test loss: 3.665273   Train accuracy 0.837209   Test accuracy is 0.340000
# Epoch: 123   Train loss: 0.677126   Test loss: 4.070541   Train accuracy 0.697674   Test accuracy is 0.360000
# Epoch: 124   Train loss: 0.725159   Test loss: 3.398746   Train accuracy 0.627907   Test accuracy is 0.360000
# Epoch: 125   Train loss: 0.484540   Test loss: 2.433274   Train accuracy 0.767442   Test accuracy is 0.400000
# Epoch: 126   Train loss: 0.349389   Test loss: 2.531535   Train accuracy 0.860465   Test accuracy is 0.460000
# Epoch: 127   Train loss: 0.587902   Test loss: 4.065761   Train accuracy 0.744186   Test accuracy is 0.320000
# Epoch: 128   Train loss: 0.582249   Test loss: 4.094342   Train accuracy 0.744186   Test accuracy is 0.380000
# Epoch: 129   Train loss: 0.617065   Test loss: 3.465216   Train accuracy 0.744186   Test accuracy is 0.380000
# Epoch: 130   Train loss: 0.540632   Test loss: 2.995759   Train accuracy 0.767442   Test accuracy is 0.440000
# Epoch: 131   Train loss: 0.475547   Test loss: 4.468531   Train accuracy 0.860465   Test accuracy is 0.340000
# Epoch: 132   Train loss: 0.563488   Test loss: 3.521659   Train accuracy 0.790698   Test accuracy is 0.420000
# Epoch: 133   Train loss: 0.505236   Test loss: 4.116587   Train accuracy 0.744186   Test accuracy is 0.360000
# Epoch: 134   Train loss: 0.347568   Test loss: 4.573302   Train accuracy 0.906977   Test accuracy is 0.360000
# Epoch: 135   Train loss: 0.573563   Test loss: 3.666219   Train accuracy 0.744186   Test accuracy is 0.360000
# Epoch: 136   Train loss: 0.317353   Test loss: 3.752102   Train accuracy 0.930233   Test accuracy is 0.380000
# Epoch: 137   Train loss: 0.435932   Test loss: 4.283434   Train accuracy 0.837209   Test accuracy is 0.360000
# Epoch: 138   Train loss: 0.534424   Test loss: 2.293801   Train accuracy 0.767442   Test accuracy is 0.480000
# Epoch: 139   Train loss: 0.401247   Test loss: 2.985170   Train accuracy 0.860465   Test accuracy is 0.420000
# Epoch: 140   Train loss: 0.468905   Test loss: 5.048445   Train accuracy 0.813953   Test accuracy is 0.320000
# Epoch: 141   Train loss: 0.365193   Test loss: 2.842827   Train accuracy 0.930233   Test accuracy is 0.460000
# Epoch: 142   Train loss: 0.399102   Test loss: 3.479171   Train accuracy 0.883721   Test accuracy is 0.460000
# Epoch: 143   Train loss: 0.478086   Test loss: 4.156443   Train accuracy 0.883721   Test accuracy is 0.420000
# Epoch: 144   Train loss: 0.501628   Test loss: 3.656726   Train accuracy 0.860465   Test accuracy is 0.480000
# Epoch: 145   Train loss: 0.265171   Test loss: 2.519909   Train accuracy 0.906977   Test accuracy is 0.480000
# Epoch: 146   Train loss: 0.379395   Test loss: 3.572210   Train accuracy 0.813953   Test accuracy is 0.420000
# Epoch: 147   Train loss: 0.334227   Test loss: 3.934458   Train accuracy 0.883721   Test accuracy is 0.320000
# Epoch: 148   Train loss: 0.586964   Test loss: 3.675504   Train accuracy 0.767442   Test accuracy is 0.400000
# Epoch: 149   Train loss: 0.406369   Test loss: 2.695052   Train accuracy 0.837209   Test accuracy is 0.480000
# The average accuracy is: 0.3193333333333333
# The best accuracy is: 0.48
# THE BEST ACCURACY IS 0.48
# subject 20 duration: 0:00:42.469440
# seed is 701
# Subject 21
# Epoch: 0   Train loss: 1.455686   Test loss: 1.372459   Train accuracy 0.279070   Test accuracy is 0.320000
# Epoch: 1   Train loss: 1.411548   Test loss: 1.384916   Train accuracy 0.232558   Test accuracy is 0.220000
# Epoch: 2   Train loss: 1.446637   Test loss: 1.393982   Train accuracy 0.302326   Test accuracy is 0.180000
# Epoch: 3   Train loss: 1.397164   Test loss: 1.382159   Train accuracy 0.255814   Test accuracy is 0.400000
# Epoch: 4   Train loss: 1.401056   Test loss: 1.380507   Train accuracy 0.209302   Test accuracy is 0.280000
# Epoch: 5   Train loss: 1.395709   Test loss: 1.379745   Train accuracy 0.255814   Test accuracy is 0.180000
# Epoch: 6   Train loss: 1.375509   Test loss: 1.380291   Train accuracy 0.279070   Test accuracy is 0.180000
# Epoch: 7   Train loss: 1.445745   Test loss: 1.370167   Train accuracy 0.302326   Test accuracy is 0.360000
# Epoch: 8   Train loss: 1.338016   Test loss: 1.366251   Train accuracy 0.302326   Test accuracy is 0.380000
# Epoch: 9   Train loss: 1.371584   Test loss: 1.351529   Train accuracy 0.302326   Test accuracy is 0.420000
# Epoch: 10   Train loss: 1.407361   Test loss: 1.348161   Train accuracy 0.255814   Test accuracy is 0.380000
# Epoch: 11   Train loss: 1.330711   Test loss: 1.367195   Train accuracy 0.325581   Test accuracy is 0.400000
# Epoch: 12   Train loss: 1.393391   Test loss: 1.339237   Train accuracy 0.255814   Test accuracy is 0.340000
# Epoch: 13   Train loss: 1.348485   Test loss: 1.331286   Train accuracy 0.372093   Test accuracy is 0.420000
# Epoch: 14   Train loss: 1.272647   Test loss: 1.414388   Train accuracy 0.465116   Test accuracy is 0.340000
# Epoch: 15   Train loss: 1.259579   Test loss: 1.411410   Train accuracy 0.418605   Test accuracy is 0.360000
# Epoch: 16   Train loss: 1.370049   Test loss: 1.520333   Train accuracy 0.186047   Test accuracy is 0.320000
# Epoch: 17   Train loss: 1.265445   Test loss: 1.454492   Train accuracy 0.325581   Test accuracy is 0.360000
# Epoch: 18   Train loss: 1.309501   Test loss: 1.605497   Train accuracy 0.302326   Test accuracy is 0.340000
# Epoch: 19   Train loss: 1.203921   Test loss: 1.714310   Train accuracy 0.348837   Test accuracy is 0.340000
# Epoch: 20   Train loss: 1.233881   Test loss: 2.007678   Train accuracy 0.348837   Test accuracy is 0.240000
# Epoch: 21   Train loss: 1.113245   Test loss: 1.938756   Train accuracy 0.558140   Test accuracy is 0.220000
# Epoch: 22   Train loss: 1.075342   Test loss: 1.852319   Train accuracy 0.511628   Test accuracy is 0.320000
# Epoch: 23   Train loss: 0.972125   Test loss: 1.827373   Train accuracy 0.558140   Test accuracy is 0.360000
# Epoch: 24   Train loss: 1.035028   Test loss: 1.902714   Train accuracy 0.511628   Test accuracy is 0.300000
# Epoch: 25   Train loss: 0.955167   Test loss: 1.808546   Train accuracy 0.581395   Test accuracy is 0.320000
# Epoch: 26   Train loss: 0.957020   Test loss: 1.734962   Train accuracy 0.558140   Test accuracy is 0.380000
# Epoch: 27   Train loss: 1.051652   Test loss: 2.528679   Train accuracy 0.488372   Test accuracy is 0.280000
# Epoch: 28   Train loss: 1.116620   Test loss: 3.703038   Train accuracy 0.372093   Test accuracy is 0.180000
# Epoch: 29   Train loss: 1.022227   Test loss: 1.649252   Train accuracy 0.511628   Test accuracy is 0.400000
# Epoch: 30   Train loss: 1.018498   Test loss: 2.081138   Train accuracy 0.534884   Test accuracy is 0.320000
# Epoch: 31   Train loss: 0.933014   Test loss: 1.753309   Train accuracy 0.558140   Test accuracy is 0.400000
# Epoch: 32   Train loss: 0.928752   Test loss: 1.875566   Train accuracy 0.627907   Test accuracy is 0.380000
# Epoch: 33   Train loss: 0.829065   Test loss: 1.744683   Train accuracy 0.720930   Test accuracy is 0.340000
# Epoch: 34   Train loss: 0.838113   Test loss: 3.055257   Train accuracy 0.627907   Test accuracy is 0.240000
# Epoch: 35   Train loss: 0.734774   Test loss: 3.767203   Train accuracy 0.651163   Test accuracy is 0.220000
# Epoch: 36   Train loss: 0.941201   Test loss: 2.607746   Train accuracy 0.604651   Test accuracy is 0.320000
# Epoch: 37   Train loss: 0.986838   Test loss: 1.571289   Train accuracy 0.465116   Test accuracy is 0.440000
# Epoch: 38   Train loss: 0.778624   Test loss: 2.080021   Train accuracy 0.627907   Test accuracy is 0.340000
# Epoch: 39   Train loss: 0.811978   Test loss: 1.477693   Train accuracy 0.511628   Test accuracy is 0.480000
# Epoch: 40   Train loss: 0.918724   Test loss: 1.445283   Train accuracy 0.558140   Test accuracy is 0.440000
# Epoch: 41   Train loss: 0.935297   Test loss: 2.105671   Train accuracy 0.488372   Test accuracy is 0.320000
# Epoch: 42   Train loss: 0.778709   Test loss: 2.146251   Train accuracy 0.627907   Test accuracy is 0.360000
# Epoch: 43   Train loss: 0.709171   Test loss: 1.967153   Train accuracy 0.651163   Test accuracy is 0.400000
# Epoch: 44   Train loss: 0.843343   Test loss: 1.710252   Train accuracy 0.581395   Test accuracy is 0.340000
# Epoch: 45   Train loss: 0.838217   Test loss: 1.526922   Train accuracy 0.581395   Test accuracy is 0.420000
# Epoch: 46   Train loss: 0.952914   Test loss: 2.176180   Train accuracy 0.488372   Test accuracy is 0.400000
# Epoch: 47   Train loss: 0.752674   Test loss: 1.639562   Train accuracy 0.697674   Test accuracy is 0.420000
# Epoch: 48   Train loss: 0.831144   Test loss: 1.680484   Train accuracy 0.627907   Test accuracy is 0.480000
# Epoch: 49   Train loss: 0.774670   Test loss: 3.013624   Train accuracy 0.697674   Test accuracy is 0.280000
# Epoch: 50   Train loss: 0.676212   Test loss: 1.677055   Train accuracy 0.674419   Test accuracy is 0.420000
# Epoch: 51   Train loss: 0.671170   Test loss: 2.419273   Train accuracy 0.813953   Test accuracy is 0.360000
# Epoch: 52   Train loss: 0.716301   Test loss: 1.819233   Train accuracy 0.627907   Test accuracy is 0.380000
# Epoch: 53   Train loss: 0.673925   Test loss: 2.487417   Train accuracy 0.697674   Test accuracy is 0.340000
# Epoch: 54   Train loss: 0.778042   Test loss: 2.203612   Train accuracy 0.651163   Test accuracy is 0.440000
# Epoch: 55   Train loss: 0.675728   Test loss: 1.843646   Train accuracy 0.651163   Test accuracy is 0.360000
# Epoch: 56   Train loss: 0.743404   Test loss: 1.815573   Train accuracy 0.651163   Test accuracy is 0.420000
# Epoch: 57   Train loss: 0.702914   Test loss: 1.963763   Train accuracy 0.767442   Test accuracy is 0.420000
# Epoch: 58   Train loss: 0.772631   Test loss: 1.624418   Train accuracy 0.697674   Test accuracy is 0.380000
# Epoch: 59   Train loss: 0.700092   Test loss: 2.561061   Train accuracy 0.627907   Test accuracy is 0.320000
# Epoch: 60   Train loss: 0.676065   Test loss: 2.280998   Train accuracy 0.697674   Test accuracy is 0.420000
# Epoch: 61   Train loss: 0.783678   Test loss: 1.853251   Train accuracy 0.697674   Test accuracy is 0.440000
# Epoch: 62   Train loss: 0.671972   Test loss: 2.425418   Train accuracy 0.697674   Test accuracy is 0.400000
# Epoch: 63   Train loss: 0.569175   Test loss: 2.005019   Train accuracy 0.790698   Test accuracy is 0.440000
# Epoch: 64   Train loss: 0.794000   Test loss: 1.624799   Train accuracy 0.604651   Test accuracy is 0.460000
# Epoch: 65   Train loss: 0.576497   Test loss: 1.729070   Train accuracy 0.697674   Test accuracy is 0.440000
# Epoch: 66   Train loss: 0.680934   Test loss: 3.297497   Train accuracy 0.651163   Test accuracy is 0.340000
# Epoch: 67   Train loss: 0.659525   Test loss: 2.761673   Train accuracy 0.697674   Test accuracy is 0.360000
# Epoch: 68   Train loss: 0.531218   Test loss: 3.594482   Train accuracy 0.813953   Test accuracy is 0.280000
# Epoch: 69   Train loss: 0.608060   Test loss: 2.574470   Train accuracy 0.720930   Test accuracy is 0.380000
# Epoch: 70   Train loss: 0.583142   Test loss: 2.080143   Train accuracy 0.720930   Test accuracy is 0.500000
# Epoch: 71   Train loss: 0.605616   Test loss: 2.154414   Train accuracy 0.674419   Test accuracy is 0.480000
# Epoch: 72   Train loss: 0.615524   Test loss: 4.273089   Train accuracy 0.767442   Test accuracy is 0.260000
# Epoch: 73   Train loss: 0.590493   Test loss: 2.783289   Train accuracy 0.720930   Test accuracy is 0.360000
# Epoch: 74   Train loss: 0.612772   Test loss: 2.843950   Train accuracy 0.790698   Test accuracy is 0.400000
# Epoch: 75   Train loss: 0.604540   Test loss: 1.694793   Train accuracy 0.767442   Test accuracy is 0.400000
# Epoch: 76   Train loss: 0.501750   Test loss: 3.535751   Train accuracy 0.860465   Test accuracy is 0.320000
# Epoch: 77   Train loss: 0.634215   Test loss: 3.055014   Train accuracy 0.720930   Test accuracy is 0.320000
# Epoch: 78   Train loss: 0.591677   Test loss: 2.051977   Train accuracy 0.720930   Test accuracy is 0.460000
# Epoch: 79   Train loss: 0.497682   Test loss: 1.823732   Train accuracy 0.790698   Test accuracy is 0.440000
# Epoch: 80   Train loss: 0.640330   Test loss: 2.014670   Train accuracy 0.813953   Test accuracy is 0.520000
# Epoch: 81   Train loss: 0.596652   Test loss: 1.950622   Train accuracy 0.790698   Test accuracy is 0.420000
# Epoch: 82   Train loss: 0.547699   Test loss: 3.806568   Train accuracy 0.813953   Test accuracy is 0.300000
# Epoch: 83   Train loss: 0.570766   Test loss: 2.519099   Train accuracy 0.744186   Test accuracy is 0.480000
# Epoch: 84   Train loss: 0.618284   Test loss: 2.652836   Train accuracy 0.697674   Test accuracy is 0.440000
# Epoch: 85   Train loss: 0.407457   Test loss: 1.906618   Train accuracy 0.860465   Test accuracy is 0.480000
# Epoch: 86   Train loss: 0.440944   Test loss: 5.114553   Train accuracy 0.790698   Test accuracy is 0.260000
# Epoch: 87   Train loss: 0.488890   Test loss: 2.738106   Train accuracy 0.813953   Test accuracy is 0.400000
# Epoch: 88   Train loss: 0.524737   Test loss: 2.414625   Train accuracy 0.813953   Test accuracy is 0.520000
# Epoch: 89   Train loss: 0.609208   Test loss: 2.729884   Train accuracy 0.744186   Test accuracy is 0.340000
# Epoch: 90   Train loss: 0.525045   Test loss: 2.754802   Train accuracy 0.813953   Test accuracy is 0.460000
# Epoch: 91   Train loss: 0.578362   Test loss: 3.412369   Train accuracy 0.790698   Test accuracy is 0.400000
# Epoch: 92   Train loss: 0.398812   Test loss: 7.409039   Train accuracy 0.837209   Test accuracy is 0.220000
# Epoch: 93   Train loss: 0.353333   Test loss: 2.010540   Train accuracy 0.883721   Test accuracy is 0.480000
# Epoch: 94   Train loss: 0.442923   Test loss: 2.257818   Train accuracy 0.790698   Test accuracy is 0.440000
# Epoch: 95   Train loss: 0.505396   Test loss: 1.804395   Train accuracy 0.744186   Test accuracy is 0.560000
# Epoch: 96   Train loss: 0.538668   Test loss: 1.816247   Train accuracy 0.813953   Test accuracy is 0.560000
# Epoch: 97   Train loss: 0.424287   Test loss: 1.793113   Train accuracy 0.813953   Test accuracy is 0.580000
# Epoch: 98   Train loss: 0.436773   Test loss: 1.914570   Train accuracy 0.790698   Test accuracy is 0.440000
# Epoch: 99   Train loss: 0.544920   Test loss: 1.861898   Train accuracy 0.767442   Test accuracy is 0.560000
# Epoch: 100   Train loss: 0.412744   Test loss: 2.487008   Train accuracy 0.813953   Test accuracy is 0.440000
# Epoch: 101   Train loss: 0.308948   Test loss: 3.665972   Train accuracy 0.906977   Test accuracy is 0.280000
# Epoch: 102   Train loss: 0.313199   Test loss: 7.515309   Train accuracy 0.837209   Test accuracy is 0.220000
# Epoch: 103   Train loss: 0.463351   Test loss: 2.401748   Train accuracy 0.813953   Test accuracy is 0.520000
# Epoch: 104   Train loss: 0.581803   Test loss: 1.860703   Train accuracy 0.767442   Test accuracy is 0.500000
# Epoch: 105   Train loss: 0.388050   Test loss: 2.427131   Train accuracy 0.860465   Test accuracy is 0.500000
# Epoch: 106   Train loss: 0.298505   Test loss: 2.137086   Train accuracy 0.930233   Test accuracy is 0.500000
# Epoch: 107   Train loss: 0.323064   Test loss: 2.340903   Train accuracy 0.860465   Test accuracy is 0.460000
# Epoch: 108   Train loss: 0.371608   Test loss: 2.725785   Train accuracy 0.837209   Test accuracy is 0.380000
# Epoch: 109   Train loss: 0.187413   Test loss: 2.284317   Train accuracy 0.930233   Test accuracy is 0.480000
# Epoch: 110   Train loss: 0.505681   Test loss: 2.273489   Train accuracy 0.837209   Test accuracy is 0.520000
# Epoch: 111   Train loss: 0.338056   Test loss: 3.403624   Train accuracy 0.883721   Test accuracy is 0.420000
# Epoch: 112   Train loss: 0.392636   Test loss: 2.188712   Train accuracy 0.906977   Test accuracy is 0.420000
# Epoch: 113   Train loss: 0.309219   Test loss: 2.201530   Train accuracy 0.906977   Test accuracy is 0.460000
# Epoch: 114   Train loss: 0.390799   Test loss: 2.659227   Train accuracy 0.860465   Test accuracy is 0.520000
# Epoch: 115   Train loss: 0.240182   Test loss: 2.311461   Train accuracy 0.860465   Test accuracy is 0.540000
# Epoch: 116   Train loss: 0.428408   Test loss: 2.816174   Train accuracy 0.813953   Test accuracy is 0.500000
# Epoch: 117   Train loss: 0.319806   Test loss: 3.086945   Train accuracy 0.883721   Test accuracy is 0.500000
# Epoch: 118   Train loss: 0.285703   Test loss: 2.345143   Train accuracy 0.860465   Test accuracy is 0.460000
# Epoch: 119   Train loss: 0.344776   Test loss: 4.478501   Train accuracy 0.883721   Test accuracy is 0.320000
# Epoch: 120   Train loss: 0.294465   Test loss: 2.832820   Train accuracy 0.906977   Test accuracy is 0.380000
# Epoch: 121   Train loss: 0.352316   Test loss: 5.589192   Train accuracy 0.837209   Test accuracy is 0.280000
# Epoch: 122   Train loss: 0.379374   Test loss: 3.230590   Train accuracy 0.837209   Test accuracy is 0.480000
# Epoch: 123   Train loss: 0.307107   Test loss: 2.832823   Train accuracy 0.837209   Test accuracy is 0.440000
# Epoch: 124   Train loss: 0.293292   Test loss: 2.350805   Train accuracy 0.906977   Test accuracy is 0.440000
# Epoch: 125   Train loss: 0.327109   Test loss: 2.621786   Train accuracy 0.883721   Test accuracy is 0.480000
# Epoch: 126   Train loss: 0.389779   Test loss: 2.120406   Train accuracy 0.860465   Test accuracy is 0.480000
# Epoch: 127   Train loss: 0.236911   Test loss: 5.407380   Train accuracy 0.906977   Test accuracy is 0.280000
# Epoch: 128   Train loss: 0.371433   Test loss: 3.993737   Train accuracy 0.883721   Test accuracy is 0.320000
# Epoch: 129   Train loss: 0.164730   Test loss: 2.305270   Train accuracy 0.930233   Test accuracy is 0.480000
# Epoch: 130   Train loss: 0.279089   Test loss: 2.349360   Train accuracy 0.930233   Test accuracy is 0.360000
# ...
# Epoch: 6   Train loss: 1.467127   Test loss: 1.389628   Train accuracy 0.139535   Test accuracy is 0.220000
# Epoch: 7   Train loss: 1.425118   Test loss: 1.386060   Train accuracy 0.255814   Test accuracy is 0.200000
# Epoch: 8   Train loss: 1.427865   Test loss: 1.389047   Train accuracy 0.162791   Test accuracy is 0.220000
# Epoch: 9   Train loss: 1.394553   Test loss: 1.381613   Train accuracy 0.255814   Test accuracy is 0.220000
# Epoch: 10   Train loss: 1.342550   Test loss: 1.376723   Train accuracy 0.372093   Test accuracy is 0.240000
# Epoch: 11   Train loss: 1.387277   Test loss: 1.368985   Train accuracy 0.302326   Test accuracy is 0.240000
# Epoch: 12   Train loss: 1.335054   Test loss: 1.357582   Train accuracy 0.372093   Test accuracy is 0.260000
# Epoch: 13   Train loss: 1.342086   Test loss: 1.347514   Train accuracy 0.418605   Test accuracy is 0.280000
# Epoch: 14   Train loss: 1.427081   Test loss: 1.325449   Train accuracy 0.116279   Test accuracy is 0.320000
# Epoch: 15   Train loss: 1.376448   Test loss: 1.311013   Train accuracy 0.162791   Test accuracy is 0.340000
# Epoch: 16   Train loss: 1.325598   Test loss: 1.289087   Train accuracy 0.395349   Test accuracy is 0.340000
# Epoch: 17   Train loss: 1.324492   Test loss: 1.282266   Train accuracy 0.325581   Test accuracy is 0.340000
# Epoch: 18   Train loss: 1.284793   Test loss: 1.274709   Train accuracy 0.465116   Test accuracy is 0.360000
# Epoch: 19   Train loss: 1.278992   Test loss: 1.335665   Train accuracy 0.441860   Test accuracy is 0.320000
# Epoch: 20   Train loss: 1.246287   Test loss: 1.281749   Train accuracy 0.372093   Test accuracy is 0.380000
# Epoch: 21   Train loss: 1.231294   Test loss: 1.514326   Train accuracy 0.372093   Test accuracy is 0.240000
# Epoch: 22   Train loss: 1.068097   Test loss: 1.497347   Train accuracy 0.604651   Test accuracy is 0.320000
# Epoch: 23   Train loss: 1.181534   Test loss: 1.354233   Train accuracy 0.441860   Test accuracy is 0.400000
# Epoch: 24   Train loss: 1.022868   Test loss: 1.485437   Train accuracy 0.534884   Test accuracy is 0.400000
# Epoch: 25   Train loss: 0.855483   Test loss: 1.236835   Train accuracy 0.744186   Test accuracy is 0.440000
# Epoch: 26   Train loss: 1.106607   Test loss: 1.252600   Train accuracy 0.534884   Test accuracy is 0.440000
# Epoch: 27   Train loss: 0.928538   Test loss: 1.223964   Train accuracy 0.651163   Test accuracy is 0.480000
# Epoch: 28   Train loss: 1.008073   Test loss: 1.419538   Train accuracy 0.511628   Test accuracy is 0.440000
# Epoch: 29   Train loss: 0.906216   Test loss: 1.650509   Train accuracy 0.651163   Test accuracy is 0.460000
# Epoch: 30   Train loss: 0.800635   Test loss: 1.119456   Train accuracy 0.604651   Test accuracy is 0.540000
# Epoch: 31   Train loss: 0.725977   Test loss: 1.297889   Train accuracy 0.697674   Test accuracy is 0.460000
# Epoch: 32   Train loss: 0.705940   Test loss: 1.475310   Train accuracy 0.720930   Test accuracy is 0.500000
# Epoch: 33   Train loss: 0.744881   Test loss: 2.209072   Train accuracy 0.720930   Test accuracy is 0.340000
# Epoch: 34   Train loss: 0.732734   Test loss: 1.794588   Train accuracy 0.674419   Test accuracy is 0.440000
# Epoch: 35   Train loss: 0.778121   Test loss: 1.888586   Train accuracy 0.651163   Test accuracy is 0.400000
# Epoch: 36   Train loss: 0.788448   Test loss: 2.099453   Train accuracy 0.697674   Test accuracy is 0.480000
# Epoch: 37   Train loss: 0.665006   Test loss: 1.114473   Train accuracy 0.790698   Test accuracy is 0.600000
# Epoch: 38   Train loss: 0.736263   Test loss: 2.325413   Train accuracy 0.674419   Test accuracy is 0.340000
# Epoch: 39   Train loss: 0.644193   Test loss: 1.233680   Train accuracy 0.674419   Test accuracy is 0.560000
# Epoch: 40   Train loss: 0.622803   Test loss: 1.930803   Train accuracy 0.767442   Test accuracy is 0.440000
# Epoch: 41   Train loss: 0.556191   Test loss: 1.795770   Train accuracy 0.744186   Test accuracy is 0.460000
# Epoch: 42   Train loss: 0.737486   Test loss: 1.920310   Train accuracy 0.744186   Test accuracy is 0.480000
# Epoch: 43   Train loss: 0.624064   Test loss: 1.538859   Train accuracy 0.767442   Test accuracy is 0.520000
# Epoch: 44   Train loss: 0.615005   Test loss: 1.308732   Train accuracy 0.790698   Test accuracy is 0.580000
# Epoch: 45   Train loss: 0.541786   Test loss: 1.034878   Train accuracy 0.767442   Test accuracy is 0.640000
# Epoch: 46   Train loss: 0.789839   Test loss: 1.733489   Train accuracy 0.697674   Test accuracy is 0.520000
# Epoch: 47   Train loss: 0.409371   Test loss: 2.253256   Train accuracy 0.860465   Test accuracy is 0.440000
# Epoch: 48   Train loss: 0.458683   Test loss: 1.934770   Train accuracy 0.813953   Test accuracy is 0.560000
# Epoch: 49   Train loss: 0.462358   Test loss: 1.445004   Train accuracy 0.813953   Test accuracy is 0.560000
# Epoch: 50   Train loss: 0.298520   Test loss: 1.780206   Train accuracy 0.883721   Test accuracy is 0.540000
# Epoch: 51   Train loss: 0.484489   Test loss: 1.533120   Train accuracy 0.813953   Test accuracy is 0.580000
# Epoch: 52   Train loss: 0.300505   Test loss: 1.738557   Train accuracy 0.930233   Test accuracy is 0.580000
# Epoch: 53   Train loss: 0.381746   Test loss: 1.641650   Train accuracy 0.906977   Test accuracy is 0.620000
# Epoch: 54   Train loss: 0.306518   Test loss: 1.470842   Train accuracy 0.906977   Test accuracy is 0.580000
# Epoch: 55   Train loss: 0.559883   Test loss: 2.011661   Train accuracy 0.837209   Test accuracy is 0.560000
# Epoch: 56   Train loss: 0.276069   Test loss: 2.370830   Train accuracy 0.906977   Test accuracy is 0.600000
# Epoch: 57   Train loss: 0.423071   Test loss: 1.957504   Train accuracy 0.790698   Test accuracy is 0.520000
# Epoch: 58   Train loss: 0.434927   Test loss: 2.259797   Train accuracy 0.767442   Test accuracy is 0.560000
# Epoch: 59   Train loss: 0.279003   Test loss: 2.281048   Train accuracy 0.883721   Test accuracy is 0.540000
# Epoch: 60   Train loss: 0.315143   Test loss: 1.220907   Train accuracy 0.906977   Test accuracy is 0.640000
# Epoch: 61   Train loss: 0.334012   Test loss: 1.149881   Train accuracy 0.837209   Test accuracy is 0.680000
# Epoch: 62   Train loss: 0.180403   Test loss: 3.005120   Train accuracy 0.930233   Test accuracy is 0.400000
# Epoch: 63   Train loss: 0.256075   Test loss: 2.361697   Train accuracy 0.906977   Test accuracy is 0.460000
# Epoch: 64   Train loss: 0.188898   Test loss: 2.068149   Train accuracy 0.953488   Test accuracy is 0.520000
# Epoch: 65   Train loss: 0.225900   Test loss: 2.354601   Train accuracy 0.930233   Test accuracy is 0.460000
# Epoch: 66   Train loss: 0.457102   Test loss: 2.190904   Train accuracy 0.790698   Test accuracy is 0.520000
# Epoch: 67   Train loss: 0.084153   Test loss: 1.640143   Train accuracy 0.976744   Test accuracy is 0.560000
# Epoch: 68   Train loss: 0.312253   Test loss: 2.001600   Train accuracy 0.906977   Test accuracy is 0.580000
# Epoch: 69   Train loss: 0.324425   Test loss: 2.863230   Train accuracy 0.883721   Test accuracy is 0.340000
# Epoch: 70   Train loss: 0.246409   Test loss: 1.570945   Train accuracy 0.883721   Test accuracy is 0.540000
# Epoch: 71   Train loss: 0.141823   Test loss: 2.079170   Train accuracy 0.953488   Test accuracy is 0.500000
# Epoch: 72   Train loss: 0.108889   Test loss: 1.584189   Train accuracy 0.953488   Test accuracy is 0.600000
# Epoch: 73   Train loss: 0.330476   Test loss: 2.787193   Train accuracy 0.837209   Test accuracy is 0.520000
# Epoch: 74   Train loss: 0.128365   Test loss: 2.734737   Train accuracy 0.976744   Test accuracy is 0.520000
# Epoch: 75   Train loss: 0.340017   Test loss: 1.510256   Train accuracy 0.883721   Test accuracy is 0.580000
# Epoch: 76   Train loss: 0.274431   Test loss: 1.314894   Train accuracy 0.860465   Test accuracy is 0.660000
# Epoch: 77   Train loss: 0.271395   Test loss: 4.032698   Train accuracy 0.860465   Test accuracy is 0.400000
# Epoch: 78   Train loss: 0.119549   Test loss: 2.389827   Train accuracy 0.976744   Test accuracy is 0.540000
# Epoch: 79   Train loss: 0.295479   Test loss: 1.551716   Train accuracy 0.906977   Test accuracy is 0.680000
# Epoch: 80   Train loss: 0.161927   Test loss: 2.497796   Train accuracy 0.976744   Test accuracy is 0.540000
# Epoch: 81   Train loss: 0.175240   Test loss: 1.988366   Train accuracy 0.953488   Test accuracy is 0.580000
# Epoch: 82   Train loss: 0.203376   Test loss: 2.763915   Train accuracy 0.976744   Test accuracy is 0.580000
# Epoch: 83   Train loss: 0.071998   Test loss: 2.058849   Train accuracy 1.000000   Test accuracy is 0.620000
# Epoch: 84   Train loss: 0.076366   Test loss: 1.080267   Train accuracy 1.000000   Test accuracy is 0.740000
# Epoch: 85   Train loss: 0.164136   Test loss: 2.438353   Train accuracy 0.930233   Test accuracy is 0.520000
# Epoch: 86   Train loss: 0.074397   Test loss: 1.925553   Train accuracy 0.976744   Test accuracy is 0.620000
# Epoch: 87   Train loss: 0.173572   Test loss: 2.573481   Train accuracy 0.953488   Test accuracy is 0.600000
# Epoch: 88   Train loss: 0.144741   Test loss: 1.813339   Train accuracy 0.906977   Test accuracy is 0.580000
# Epoch: 89   Train loss: 0.128863   Test loss: 2.126719   Train accuracy 0.953488   Test accuracy is 0.520000
# Epoch: 90   Train loss: 0.213801   Test loss: 3.365165   Train accuracy 0.906977   Test accuracy is 0.520000
# Epoch: 91   Train loss: 0.109220   Test loss: 4.370429   Train accuracy 0.976744   Test accuracy is 0.340000
# Epoch: 92   Train loss: 0.087857   Test loss: 1.683442   Train accuracy 0.976744   Test accuracy is 0.720000
# Epoch: 93   Train loss: 0.280181   Test loss: 1.964581   Train accuracy 0.930233   Test accuracy is 0.660000
# Epoch: 94   Train loss: 0.115026   Test loss: 1.502732   Train accuracy 0.953488   Test accuracy is 0.640000
# Epoch: 95   Train loss: 0.208768   Test loss: 1.994648   Train accuracy 0.930233   Test accuracy is 0.600000
# Epoch: 96   Train loss: 0.284437   Test loss: 2.819935   Train accuracy 0.883721   Test accuracy is 0.500000
# Epoch: 97   Train loss: 0.436818   Test loss: 2.109230   Train accuracy 0.837209   Test accuracy is 0.580000
# Epoch: 98   Train loss: 0.291541   Test loss: 2.957193   Train accuracy 0.906977   Test accuracy is 0.480000
# Epoch: 99   Train loss: 0.515755   Test loss: 4.027333   Train accuracy 0.860465   Test accuracy is 0.480000
# Epoch: 100   Train loss: 0.079685   Test loss: 2.792041   Train accuracy 1.000000   Test accuracy is 0.560000
# Epoch: 101   Train loss: 0.127951   Test loss: 2.412891   Train accuracy 0.953488   Test accuracy is 0.560000
# Epoch: 102   Train loss: 0.076206   Test loss: 3.194463   Train accuracy 0.953488   Test accuracy is 0.600000
# Epoch: 103   Train loss: 0.081759   Test loss: 3.419999   Train accuracy 0.953488   Test accuracy is 0.580000
# Epoch: 104   Train loss: 0.277635   Test loss: 1.650144   Train accuracy 0.883721   Test accuracy is 0.660000
# Epoch: 105   Train loss: 0.061057   Test loss: 4.186042   Train accuracy 1.000000   Test accuracy is 0.540000
# Epoch: 106   Train loss: 0.092813   Test loss: 1.844646   Train accuracy 0.953488   Test accuracy is 0.600000
# Epoch: 107   Train loss: 0.111372   Test loss: 2.825019   Train accuracy 0.976744   Test accuracy is 0.560000
# Epoch: 108   Train loss: 0.064689   Test loss: 2.533882   Train accuracy 0.976744   Test accuracy is 0.600000
# Epoch: 109   Train loss: 0.249034   Test loss: 3.425944   Train accuracy 0.906977   Test accuracy is 0.540000
# Epoch: 110   Train loss: 0.162268   Test loss: 2.330776   Train accuracy 0.976744   Test accuracy is 0.620000
# Epoch: 111   Train loss: 0.083445   Test loss: 2.109297   Train accuracy 0.976744   Test accuracy is 0.560000
# Epoch: 112   Train loss: 0.177636   Test loss: 3.661278   Train accuracy 0.930233   Test accuracy is 0.580000
# Epoch: 113   Train loss: 0.182793   Test loss: 1.807441   Train accuracy 0.930233   Test accuracy is 0.620000
# Epoch: 114   Train loss: 0.157087   Test loss: 2.143961   Train accuracy 0.953488   Test accuracy is 0.500000
# Epoch: 115   Train loss: 0.118763   Test loss: 3.696240   Train accuracy 0.953488   Test accuracy is 0.500000
# Epoch: 116   Train loss: 0.149398   Test loss: 2.130430   Train accuracy 0.930233   Test accuracy is 0.620000
# Epoch: 117   Train loss: 0.080441   Test loss: 1.660775   Train accuracy 0.976744   Test accuracy is 0.660000
# Epoch: 118   Train loss: 0.122224   Test loss: 1.327919   Train accuracy 0.930233   Test accuracy is 0.700000
# Epoch: 119   Train loss: 0.193193   Test loss: 3.004653   Train accuracy 0.930233   Test accuracy is 0.600000
# Epoch: 120   Train loss: 0.085457   Test loss: 1.905313   Train accuracy 0.953488   Test accuracy is 0.660000
# Epoch: 121   Train loss: 0.161067   Test loss: 1.994177   Train accuracy 0.953488   Test accuracy is 0.660000
# Epoch: 122   Train loss: 0.207806   Test loss: 3.260409   Train accuracy 0.930233   Test accuracy is 0.560000
# Epoch: 123   Train loss: 0.090225   Test loss: 1.937950   Train accuracy 0.976744   Test accuracy is 0.660000
# Epoch: 124   Train loss: 0.067059   Test loss: 3.923666   Train accuracy 0.976744   Test accuracy is 0.420000
# Epoch: 125   Train loss: 0.056182   Test loss: 2.298732   Train accuracy 0.976744   Test accuracy is 0.580000
# Epoch: 126   Train loss: 0.054542   Test loss: 2.082525   Train accuracy 0.976744   Test accuracy is 0.620000
# Epoch: 127   Train loss: 0.159447   Test loss: 1.635759   Train accuracy 0.976744   Test accuracy is 0.640000
# Epoch: 128   Train loss: 0.244736   Test loss: 1.873158   Train accuracy 0.906977   Test accuracy is 0.600000
# Epoch: 129   Train loss: 0.130880   Test loss: 2.652593   Train accuracy 0.953488   Test accuracy is 0.580000
# Epoch: 130   Train loss: 0.151392   Test loss: 2.533758   Train accuracy 0.953488   Test accuracy is 0.600000
# Epoch: 131   Train loss: 0.188882   Test loss: 2.220881   Train accuracy 0.953488   Test accuracy is 0.600000
# Epoch: 132   Train loss: 0.238879   Test loss: 1.723501   Train accuracy 0.906977   Test accuracy is 0.620000
# Epoch: 133   Train loss: 0.043202   Test loss: 2.208427   Train accuracy 0.976744   Test accuracy is 0.600000
# Epoch: 134   Train loss: 0.044484   Test loss: 2.587834   Train accuracy 0.976744   Test accuracy is 0.600000
# Epoch: 135   Train loss: 0.058730   Test loss: 3.306603   Train accuracy 0.976744   Test accuracy is 0.560000
# Epoch: 136   Train loss: 0.054490   Test loss: 3.662984   Train accuracy 0.976744   Test accuracy is 0.500000
# Epoch: 137   Train loss: 0.055254   Test loss: 4.499278   Train accuracy 0.976744   Test accuracy is 0.480000
# Epoch: 138   Train loss: 0.271929   Test loss: 3.503572   Train accuracy 0.906977   Test accuracy is 0.540000
# Epoch: 139   Train loss: 0.112269   Test loss: 2.568925   Train accuracy 0.930233   Test accuracy is 0.620000
# Epoch: 140   Train loss: 0.100262   Test loss: 2.751993   Train accuracy 0.930233   Test accuracy is 0.500000
# Epoch: 141   Train loss: 0.076384   Test loss: 2.579406   Train accuracy 0.976744   Test accuracy is 0.600000
# Epoch: 142   Train loss: 0.064200   Test loss: 2.552411   Train accuracy 0.976744   Test accuracy is 0.580000
# Epoch: 143   Train loss: 0.163373   Test loss: 2.829379   Train accuracy 0.976744   Test accuracy is 0.540000
# Epoch: 144   Train loss: 0.073316   Test loss: 1.828253   Train accuracy 0.976744   Test accuracy is 0.660000
# Epoch: 145   Train loss: 0.049327   Test loss: 2.107445   Train accuracy 1.000000   Test accuracy is 0.600000
# Epoch: 146   Train loss: 0.127628   Test loss: 3.602166   Train accuracy 0.930233   Test accuracy is 0.480000
# Epoch: 147   Train loss: 0.058379   Test loss: 3.024522   Train accuracy 1.000000   Test accuracy is 0.540000
# Epoch: 148   Train loss: 0.026128   Test loss: 2.081633   Train accuracy 1.000000   Test accuracy is 0.640000
# Epoch: 149   Train loss: 0.146335   Test loss: 3.506998   Train accuracy 0.953488   Test accuracy is 0.520000
# The average accuracy is: 0.5063999999999997
# The best accuracy is: 0.74
# THE BEST ACCURACY IS 0.74
# subject 50 duration: 0:00:38.534638
# Thu Jun 15 14:01:08 2023

# %%
import shutil

# Specify the source directory where the text files are located
source_directory = '/content/'

# Specify the destination directory in your Google Drive
destination_directory = '/content/drive/MyDrive/resultConformerMotor2D'

# Move all text files from the source directory to the destination directory
for file_name in os.listdir(source_directory):
    if file_name.endswith('.txt'):
        file_path = os.path.join(source_directory, file_name)
        shutil.move(file_path, destination_directory)

print("Text files moved to Google Drive successfully.")
# Out:
# Text files moved to Google Drive successfully.
